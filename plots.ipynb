# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import pickle, random, datetime, numpy as np

from environments.env import Environment
# from environments.make_envs import make_sensor_based_mdp, HEIGHT
# from environments.episodic_mdp import EpisodicMDP

# from agent.agents import NoisyDriverAgent, OptimalAgent, CopyAgent

# from experiments.pre_train_machine_policy import run_pre_train_machine
# from experiments.utils import get_trajectory_cost
# from experiments.single_team import run_single_team_exp
# from experiments.multiple_teams import run_multiple_teams_exp


# from plot.plot_regret import format_axes, latexify, COLORS, golden_ratio
from plot.plot_path import PlotPath

# np.random.seed(981276345)
# random.seed(981276345)

# %% [markdown]
# ## Environment trajectories

# %%
''' Figure 1 '''
# %matplotlib inline
from agent.agents import NoisyDriverAgent

width, height = 3, 10
def plot_trajectory(init_traffic):
    env = Environment()
    grid_world = env.generate_grid_world(width, height, init_traffic_level=init_traffic)
    plt_path = PlotPath(grid_world, n_try=0)
        
    # plt_path.plot(f'outputs/envs/{init_traffic}_init_traffic_level.png')
    plt_path.plot(f'{init_traffic}_init_traffic_level_test.png')
    
    # fast check if human is working. To be removed 
    human =  NoisyDriverAgent(env,2)
    grid_world.reset()
    curr_cell = grid_world.cell_types[grid_world.current_coord]
    next_r_traffic = grid_world.traffic_levels[1]
    s0 = [curr_cell, next_r_traffic]
    for a in range(3):    
        next_coords,_ = grid_world.next_cell(a, False)
        is_wall = a!=1 and next_coords[0] == grid_world.current_coord[0]  
        next_cell_type= 'wall' if is_wall else grid_world.cell_types[next_coords]
        s0.append(next_cell_type)

    print(s0)
    print(human.take_action(s0))

plot_trajectory('no-car')
plot_trajectory('light')
plot_trajectory('heavy')
# Out:
# ['road', 'no-car', 'road', 'road', 'road']
# [0]
# ['road', 'light', 'car', 'road', 'road']
# [2]
# ['road', 'light', 'road', 'road', 'stone']
# [1]

# %% [markdown]
# ## Performance of the pre-trained machine and human policy

# %%
''' episodic MDP for the lane driving environment with sensor-based states '''

mdp = EpisodicMDP.load('outputs/MDPs/sensor_MDP')

# %%
''' load the pre-trained machine or re-train it '''

with open('outputs/agents/pre_trained_machine/machine_agent', 'rb') as file:
    machine = pickle.load(file)

# to re-train the machine policy, run the following
# machine, _ = run_pre_train_machine(env=Environment(), mdp=mdp, n_episode=5000)

# %%
''' human policy '''
human = NoisyDriverAgent(env=Environment(), mdp=mdp, noise_sd=2)
human.update_policy()

# %%
''' optimal policy '''

optimal = OptimalAgent(mdp)
optimal.update_policy()

# %%
''' performance '''
    
ep_num = 1000
agents = [CopyAgent(mdp, machine.policy), CopyAgent(mdp, human.policy), CopyAgent(mdp, optimal.policy)]
no_car_costs = []
light_heavy_costs = []

# costs for machine, human and optimal policies
for ep in range(ep_num):
    no_car_costs.append(get_trajectory_cost(agents, init_traffic='no-car'))

    traffic_level = random.choice(['light', 'heavy'])
    light_heavy_costs.append(get_trajectory_cost(agents, init_traffic=traffic_level))

print(f'no-car costs:{[sum(x) for x in zip(*no_car_costs)]},\n'
      f'light-heavy costs:{[sum(x) for x in zip(*light_heavy_costs)]}\n')
        
no_car = [sum(x) for x in zip(*no_car_costs)]
light_heavy = [sum(x) for x in zip(*light_heavy_costs)]
# Out:
# no-car costs:[816.0, 2680.0, 756.0],
# light-heavy costs:[11842.0, 5528.0, 3292.0]

# %%
''' Figure 2, choose `no_car` or `light_heavy` for fig 2(a) and 2(b) respectively'''
array = no_car

width = 1.3
height = 1

latexify(fig_height=height, fig_width=width, font_size=7, legend_size=5)

labels = [r'Machine', r'Human', r'Optimal']
x = np.arange(len(labels)) # label locations

bar_width = 0.5

fig, ax = plt.subplots()
ax = format_axes(ax)
ax.ticklabel_format(style='sci', scilimits=(3, 3), axis='y')
ax.bar(x, array, bar_width, color=[COLORS[2], COLORS[1], COLORS[0]])
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.set_ylabel(r'Total environment cost')
ax.set_xlabel(r'Policy')

plt.subplots_adjust(left=0.2, bottom=0.26, right=0.98, top=0.78, wspace=0, hspace=0)
fig.savefig('outputs/agents_performance_no_car.pdf')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# C:\Program Files\Python36\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     276                                              cwd=self.texcache,
# --> 277                                              stderr=subprocess.STDOUT)
#     278         except FileNotFoundError as exc:
#
# C:\Program Files\Python36\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#
# C:\Program Files\Python36\lib\subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     417             raise CalledProcessError(retcode, process.args,
# --> 418                                      output=stdout, stderr=stderr)
#     419     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['latex', '-interaction=nonstopmode', '--halt-on-error', 'C:\\Users\\user\\.matplotlib\\tex.cache\\78f6f39aa5797522ad9ae220d1764233.tex']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-af870e41bf2d> in <module>
#      22
#      23 plt.subplots_adjust(left=0.2, bottom=0.26, right=0.98, top=0.78, wspace=0, hspace=0)
# ---> 24 fig.savefig('outputs/agents_performance_no_car.pdf')
#      25 plt.close()
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2215                     orientation=orientation,
#    2216                     bbox_inches_restore=_bbox_inches_restore,
# -> 2217                     **kwargs)
#    2218             finally:
#    2219                 if bbox_inches and restore_bbox:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\backends\backend_pdf.py in print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2591                 RendererPdf(file, dpi, height, width),
#    2592                 bbox_inches_restore=bbox_inches_restore)
# -> 2593             self.figure.draw(renderer)
#    2594             renderer.finalize()
#    2595             if not isinstance(filename, PdfPages):
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1164         ticks_to_draw = self._update_ticks()
#    1165         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1166                                                                 renderer)
#    1167
#    1168         for tick in ticks_to_draw:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
#    1091         return ([tick.label1.get_window_extent(renderer)
# -> 1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#    1094                  for tick in ticks if tick.label2.get_visible()])
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
#    1091         return ([tick.label1.get_window_extent(renderer)
# -> 1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#    1094                  for tick in ticks if tick.label2.get_visible()])
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
# --> 289             ismath="TeX" if self.get_usetex() else False)
#     290         min_dy = (lp_h - lp_d) * self._linespacing
#     291
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\backends\_backend_pdf_ps.py in get_text_width_height_descent(self, s, prop, ismath)
#      85             fontsize = prop.get_size_in_points()
#      86             w, h, d = texmanager.get_text_width_height_descent(
# ---> 87                 s, fontsize, renderer=self)
#      88             return w, h, d
#      89         elif ismath:
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\texmanager.py in make_dvi(self, tex, fontsize)
#     309                 self._run_checked_subprocess(
#     310                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 311                      texfile], tex)
#     312             for fname in glob.glob(basefile + '*'):
#     313                 if not fname.endswith(('dvi', 'tex')):
#
# C:\Program Files\Python36\lib\site-packages\matplotlib\texmanager.py in _run_checked_subprocess(self, command, tex)
#     288                     prog=command[0],
#     289                     tex=tex.encode('unicode_escape'),
# --> 290                     exc=exc.output.decode('utf-8'))) from exc
#     291         _log.debug(report)
#     292         return report
#
# RuntimeError: latex was not able to process the following string:
# b'lp'
#
# Here is the full report generated by latex:
# latex: warning: running with administrator privileges
# This is pdfTeX, Version 3.14159265-2.6-1.40.19 (MiKTeX 2.9.6840 64-bit)
# entering extended mode
# (C:/Users/user/.matplotlib/tex.cache/78f6f39aa5797522ad9ae220d1764233.tex
# LaTeX2e <2018-04-01> patch level 5
# ("C:\Users\user\AppData\Local\Programs\MiKTeX 2.9\tex\latex\base\article.cls"
# Document Class: article 2014/09/29 v1.4h Standard LaTeX document class
# ("C:\Users\user\AppData\Local\Programs\MiKTeX 2.9\tex\latex\base\size10.clo"))
#
# ! LaTeX Error: File `type1cm.sty' not found.
#
# Type X to quit or <RETURN> to proceed,
# or enter new name. (Default extension: sty)
#
# Enter file name:
# ! Emergency stop.
# <read *>
#
# l.5 \usepackage
#                {type1ec}
# No pages of output.
# Transcript written on 78f6f39aa5797522ad9ae220d1764233.log.

# %% [markdown]
# ## Single team experiment

# %%
""" single team experiment, figure 3 (a), 4 (a) """

# will take ~ 3 hours for 20000 episodes

np.random.seed(12345)
random.seed(12345)

agents = [CopyAgent(mdp, machine.policy), human]
agents_costs = [0, 0]
switching_cost = 0
indices = list(range(10001))
plot_epochs = indices[1:20] + indices[480:501] + indices[2980:3001] + indices[9980:10001]

switching_agents, regrets = (
    run_single_team_exp(env=Environment(), mdp=mdp, n_episode=20001, agents=agents, agents_cost=agents_costs,
                        switching_cost=switching_cost, time_changing=[0], unknown_agents=[1], n_try=1,
                        plot_epochs=plot_epochs, plot_dir='outputs/epoch_plots/without_costs/')
)
# Out:
# 2021-02-19 11:43:08.484273, Episode 0,
# cumulative costs: {'ucrl2_mc': 0.0, 'ucrl2': 0.0, 'human_only': 2.0, 'machine_only': 0.0}
#
# 2021-02-19 11:46:01.506329, Episode 500,
# cumulative costs: {'ucrl2_mc': 1428.0, 'ucrl2': 1394.0, 'human_only': 520.0, 'machine_only': 2566.0}
#
# 2021-02-19 11:50:08.098815, Episode 1000,
# cumulative costs: {'ucrl2_mc': 2436.0, 'ucrl2': 2370.0, 'human_only': 1034.0, 'machine_only': 4752.0}
#
# 2021-02-19 11:54:33.677750, Episode 1500,
# cumulative costs: {'ucrl2_mc': 3328.0, 'ucrl2': 3174.0, 'human_only': 1800.0, 'machine_only': 7134.0}
#
# 2021-02-19 11:59:16.405329, Episode 2000,
# cumulative costs: {'ucrl2_mc': 3752.0, 'ucrl2': 3638.0, 'human_only': 2500.0, 'machine_only': 9414.0}
#
# 2021-02-19 12:04:55.805930, Episode 2500,
# cumulative costs: {'ucrl2_mc': 3878.0, 'ucrl2': 3724.0, 'human_only': 3166.0, 'machine_only': 11694.0}
#
# 2021-02-19 12:09:49.011586, Episode 3000,
# cumulative costs: {'ucrl2_mc': 4026.0, 'ucrl2': 3864.0, 'human_only': 3904.0, 'machine_only': 14090.0}

# %%
""" single team experiment, figure 3 (b), 4 (b) """

# will take ~ 3 hours for 20000 episodes
np.random.seed(12345)
random.seed(12345)

agents = [CopyAgent(mdp, machine.policy), human]
agents_costs = [0.0, 0.2]
switching_cost = 0.1
indices = list(range(10001))
plot_epochs = indices[1:20] + indices[480:501] + indices[2980:3001] + indices[9980:10001]

switching_agents, costs_regrets = (
    run_single_team_exp(env=Environment(), mdp=mdp, n_episode=20001, agents=agents, agents_cost=agents_costs,
                        switching_cost=switching_cost, time_changing=[0], unknown_agents=[1], n_try=1,
                        plot_epochs=plot_epochs, plot_dir='outputs/epoch_plots/with_costs/')
)
# Out:
# 2021-02-19 12:16:53.182868, Episode 0,
# cumulative costs: {'ucrl2_mc': -0.3999999999999999, 'ucrl2': -0.3999999999999999, 'human_only': 3.4000000000000017, 'machine_only': -0.3999999999999999}
#
# 2021-02-19 12:19:24.175166, Episode 500,
# cumulative costs: {'ucrl2_mc': 2039.8, 'ucrl2': 2025.7999999999995, 'human_only': 1143.9999999999943, 'machine_only': 2262.199999999999}
#
# 2021-02-19 12:22:44.323616, Episode 1000,
# cumulative costs: {'ucrl2_mc': 3169.000000000004, 'ucrl2': 2954.9000000000033, 'human_only': 2279.5999999999976, 'machine_only': 4177.7999999999965}
#
# 2021-02-19 12:26:32.849410, Episode 1500,
# cumulative costs: {'ucrl2_mc': 3986.300000000012, 'ucrl2': 3611.8000000000093, 'human_only': 3597.900000000049, 'machine_only': 6264.099999999996}
#
# 2021-02-19 12:30:34.860978, Episode 2000,
# cumulative costs: {'ucrl2_mc': 4254.100000000006, 'ucrl2': 3921.7000000000135, 'human_only': 4912.200000000099, 'machine_only': 8218.399999999994}
#
# 2021-02-19 12:35:59.802274, Episode 2500,
# cumulative costs: {'ucrl2_mc': 4419.99999999999, 'ucrl2': 4022.4000000000133, 'human_only': 6200.300000000149, 'machine_only': 10200.500000000005}
#
# 2021-02-19 12:40:51.776588, Episode 3000,
# cumulative costs: {'ucrl2_mc': 4529.499999999989, 'ucrl2': 4143.100000000018, 'human_only': 7507.500000000191, 'machine_only': 12275.700000000035}

# %%
''' plot the regret results for single team (Figure 4) '''

# you can run the above cells or load the saved regret results 

# for figure 4(b) load file `switching_regrets_s0`, for figure 4(a) load file `switching_regrets_s01`
with open('outputs/agents/single_team/switching_regrets_s01', 'rb') as file:
    regrets = pickle.load(file)

width = 1.3
height = 1

latexify(fig_height=height, fig_width=width, font_size=7, legend_size=5)
line_width = 0.8
line_style='solid'

plt.figure(1)
fig, ax = plt.subplots()
ax = format_axes(ax)
ax.ticklabel_format(style='sci', scilimits=(3, 3), axis='y')
ax.ticklabel_format(style='sci', scilimits=(3, 3), axis='x')
ax.set_ylabel(r'Regret, $R(T)$')
ax.set_xlabel(r'Episode, $k$')

ax.plot(np.cumsum(regrets['ucrl2_mc']),color=COLORS[0], label=r'UCRL2-MC', linestyle=line_style,
        linewidth=line_width)
ax.plot(np.cumsum(regrets['ucrl2']), color=COLORS[3], label=r'UCRL2', linestyle=line_style,
        linewidth=line_width)
ax.plot(np.cumsum(regrets['machine_only']), color=COLORS[2], label=r'Machine', linestyle=line_style,
        linewidth=line_width)
ax.plot(np.cumsum(regrets['human_only']), color=COLORS[1], label=r'Human', linestyle=line_style,
        linewidth=line_width)

ax.legend(frameon=False, loc=(0.0, 0.4))
plt.subplots_adjust(left=0.23, bottom=0.28, right=0.98, top=0.87, wspace=0, hspace=0)
# plt.show()
fig.savefig('outputs/single_team_s01.pdf')
plt.close()

# %% [markdown]
# ## Multiple teams experiment

# %%
""" multiple team experiment, figure 5 """

# it takes ~ 7 hours for 5000 episodes
np.random.seed(12345)
random.seed(12345)

agents = []
n_teams = 10

for n in range(n_teams):
    noise_sd = random.uniform(0, 4)
    human = NoisyDriverAgent(env=Environment(), mdp=mdp, noise_sd=noise_sd)
    human.update_policy()
    agents.append([CopyAgent(mdp, machine.policy), human])

agents_costs = [0.0, 0.2]
switching_cost = 0.1

_, regrets = (
    run_multiple_teams_exp(env=Environment(), mdp=mdp, n_teams=n_teams, n_episode=5000, agents=agents, agents_cost=agents_costs,
                        switching_cost=switching_cost, time_changing=[0], unknown_agents=[1], n_try=1)
)
# Out:
# 2021-02-19 10:55:42.279841, Episode 0, cumulative total regret: {'ucrl2_mc': 33.4, 'ucrl2': 21.4}
# 2021-02-19 10:55:57.345589, Episode 10, cumulative total regret: {'ucrl2_mc': 532.7, 'ucrl2': 510.70000000000005}
# 2021-02-19 10:56:14.699808, Episode 20, cumulative total regret: {'ucrl2_mc': 942.1999999999999, 'ucrl2': 956.0}
# 2021-02-19 10:56:33.681592, Episode 30, cumulative total regret: {'ucrl2_mc': 1458.2, 'ucrl2': 1451.3}
# 2021-02-19 10:56:54.424789, Episode 40, cumulative total regret: {'ucrl2_mc': 1864.7000000000003, 'ucrl2': 1980.9}
# 2021-02-19 10:57:17.605681, Episode 50, cumulative total regret: {'ucrl2_mc': 2191.8, 'ucrl2': 2349.4}
# 2021-02-19 10:57:41.796734, Episode 60, cumulative total regret: {'ucrl2_mc': 2512.9000000000005, 'ucrl2': 2762.5}
# 2021-02-19 10:58:07.346230, Episode 70, cumulative total regret: {'ucrl2_mc': 2806.200000000001, 'ucrl2': 3159.7999999999997}
# 2021-02-19 10:58:34.504038, Episode 80, cumulative total regret: {'ucrl2_mc': 3108.500000000001, 'ucrl2': 3577.8999999999996}
# 2021-02-19 10:59:01.755287, Episode 90, cumulative total regret: {'ucrl2_mc': 3444.2000000000003, 'ucrl2': 4084.7000000000003}
# 2021-02-19 10:59:29.737249, Episode 100, cumulative total regret: {'ucrl2_mc': 3888.9000000000005, 'ucrl2': 4487.6}
# 2021-02-19 10:59:57.631705, Episode 110, cumulative total regret: {'ucrl2_mc': 4345.100000000001, 'ucrl2': 4840.1}
# 2021-02-19 11:00:26.374063, Episode 120, cumulative total regret: {'ucrl2_mc': 4616.000000000002, 'ucrl2': 5306.5}
# 2021-02-19 11:00:56.918702, Episode 130, cumulative total regret: {'ucrl2_mc': 4809.300000000002, 'ucrl2': 5778.099999999999}
# 2021-02-19 11:01:26.315626, Episode 140, cumulative total regret: {'ucrl2_mc': 5162.900000000002, 'ucrl2': 6216.599999999999}
# 2021-02-19 11:01:57.011526, Episode 150, cumulative total regret: {'ucrl2_mc': 5386.300000000002, 'ucrl2': 6687.6}
# 2021-02-19 11:02:27.627998, Episode 160, cumulative total regret: {'ucrl2_mc': 5579.200000000002, 'ucrl2': 7057.299999999999}
# 2021-02-19 11:02:57.662583, Episode 170, cumulative total regret: {'ucrl2_mc': 5832.800000000003, 'ucrl2': 7595.2}
# 2021-02-19 11:03:28.129335, Episode 180, cumulative total regret: {'ucrl2_mc': 6032.800000000002, 'ucrl2': 8068.200000000001}
# 2021-02-19 11:04:00.141018, Episode 190, cumulative total regret: {'ucrl2_mc': 6221.900000000002, 'ucrl2': 8430.699999999999}
# 2021-02-19 11:04:30.680211, Episode 200, cumulative total regret: {'ucrl2_mc': 6430.100000000003, 'ucrl2': 8748.2}
# 2021-02-19 11:05:02.034299, Episode 210, cumulative total regret: {'ucrl2_mc': 6615.900000000003, 'ucrl2': 9208.099999999999}
# 2021-02-19 11:05:33.149483, Episode 220, cumulative total regret: {'ucrl2_mc': 6806.200000000003, 'ucrl2': 9532.300000000001}
# 2021-02-19 11:06:04.952404, Episode 230, cumulative total regret: {'ucrl2_mc': 6903.300000000001, 'ucrl2': 9983.500000000004}
# 2021-02-19 11:06:35.837587, Episode 240, cumulative total regret: {'ucrl2_mc': 7104.5, 'ucrl2': 10420.500000000002}
# 2021-02-19 11:07:07.272541, Episode 250, cumulative total regret: {'ucrl2_mc': 7304.0, 'ucrl2': 10915.000000000002}
# 2021-02-19 11:07:39.168919, Episode 260, cumulative total regret: {'ucrl2_mc': 7542.099999999999, 'ucrl2': 11329.7}
# 2021-02-19 11:08:11.436573, Episode 270, cumulative total regret: {'ucrl2_mc': 7667.1, 'ucrl2': 11781.2}
# 2021-02-19 11:08:43.997950, Episode 280, cumulative total regret: {'ucrl2_mc': 7844.700000000001, 'ucrl2': 12138.400000000003}
# 2021-02-19 11:09:16.577066, Episode 290, cumulative total regret: {'ucrl2_mc': 7978.500000000001, 'ucrl2': 12504.400000000001}
# 2021-02-19 11:09:48.882568, Episode 300, cumulative total regret: {'ucrl2_mc': 8078.900000000001, 'ucrl2': 12835.5}
# 2021-02-19 11:10:20.736763, Episode 310, cumulative total regret: {'ucrl2_mc': 8257.0, 'ucrl2': 13222.8}
# 2021-02-19 11:10:53.425756, Episode 320, cumulative total regret: {'ucrl2_mc': 8375.0, 'ucrl2': 13588.899999999998}
# 2021-02-19 11:11:25.707218, Episode 330, cumulative total regret: {'ucrl2_mc': 8608.300000000001, 'ucrl2': 14040.699999999997}
# 2021-02-19 11:11:58.167526, Episode 340, cumulative total regret: {'ucrl2_mc': 8773.900000000001, 'ucrl2': 14364.499999999996}
# 2021-02-19 11:12:31.036271, Episode 350, cumulative total regret: {'ucrl2_mc': 8888.2, 'ucrl2': 14665.799999999996}
# 2021-02-19 11:13:03.903784, Episode 360, cumulative total regret: {'ucrl2_mc': 9028.500000000002, 'ucrl2': 15057.799999999997}
# 2021-02-19 11:13:36.226670, Episode 370, cumulative total regret: {'ucrl2_mc': 9113.600000000002, 'ucrl2': 15472.099999999999}
# 2021-02-19 11:14:09.252025, Episode 380, cumulative total regret: {'ucrl2_mc': 9235.300000000001, 'ucrl2': 15818.599999999999}
# 2021-02-19 11:14:42.395258, Episode 390, cumulative total regret: {'ucrl2_mc': 9366.1, 'ucrl2': 16187.7}
# 2021-02-19 11:15:16.010639, Episode 400, cumulative total regret: {'ucrl2_mc': 9441.3, 'ucrl2': 16517.2}
# 2021-02-19 11:15:49.207359, Episode 410, cumulative total regret: {'ucrl2_mc': 9533.800000000001, 'ucrl2': 16883.500000000004}
# 2021-02-19 11:16:21.978985, Episode 420, cumulative total regret: {'ucrl2_mc': 9619.900000000001, 'ucrl2': 17319.400000000005}
# 2021-02-19 11:16:55.415371, Episode 430, cumulative total regret: {'ucrl2_mc': 9715.800000000001, 'ucrl2': 17675.2}
# 2021-02-19 11:17:28.429177, Episode 440, cumulative total regret: {'ucrl2_mc': 9808.1, 'ucrl2': 18000.6}
# 2021-02-19 11:18:01.823430, Episode 450, cumulative total regret: {'ucrl2_mc': 9910.599999999997, 'ucrl2': 18419.199999999997}
# 2021-02-19 11:18:34.718179, Episode 460, cumulative total regret: {'ucrl2_mc': 10033.799999999994, 'ucrl2': 18856.0}
# 2021-02-19 11:19:08.095356, Episode 470, cumulative total regret: {'ucrl2_mc': 10124.099999999993, 'ucrl2': 19224.600000000006}
# 2021-02-19 11:19:41.224159, Episode 480, cumulative total regret: {'ucrl2_mc': 10226.899999999992, 'ucrl2': 19637.800000000003}
# 2021-02-19 11:20:14.007439, Episode 490, cumulative total regret: {'ucrl2_mc': 10315.399999999989, 'ucrl2': 19944.200000000004}
# 2021-02-19 11:20:47.775237, Episode 500, cumulative total regret: {'ucrl2_mc': 10383.79999999999, 'ucrl2': 20290.700000000008}
# 2021-02-19 11:21:21.764797, Episode 510, cumulative total regret: {'ucrl2_mc': 10493.399999999989, 'ucrl2': 20603.000000000007}
# 2021-02-19 11:21:55.964753, Episode 520, cumulative total regret: {'ucrl2_mc': 10564.299999999987, 'ucrl2': 20988.10000000001}
# 2021-02-19 11:22:30.460713, Episode 530, cumulative total regret: {'ucrl2_mc': 10570.699999999988, 'ucrl2': 21329.100000000013}
# 2021-02-19 11:23:05.181441, Episode 540, cumulative total regret: {'ucrl2_mc': 10591.299999999988, 'ucrl2': 21561.800000000003}
# 2021-02-19 11:23:39.198947, Episode 550, cumulative total regret: {'ucrl2_mc': 10622.699999999988, 'ucrl2': 21914.000000000007}
# 2021-02-19 11:24:13.292652, Episode 560, cumulative total regret: {'ucrl2_mc': 10764.599999999988, 'ucrl2': 22314.200000000008}
# 2021-02-19 11:24:47.759434, Episode 570, cumulative total regret: {'ucrl2_mc': 10850.79999999999, 'ucrl2': 22770.100000000006}
# 2021-02-19 11:25:21.815120, Episode 580, cumulative total regret: {'ucrl2_mc': 10877.69999999999, 'ucrl2': 23115.800000000007}
# 2021-02-19 11:25:56.284567, Episode 590, cumulative total regret: {'ucrl2_mc': 10948.899999999989, 'ucrl2': 23368.600000000002}
# 2021-02-19 11:26:31.121074, Episode 600, cumulative total regret: {'ucrl2_mc': 11005.499999999989, 'ucrl2': 23655.700000000004}
# 2021-02-19 11:27:05.520207, Episode 610, cumulative total regret: {'ucrl2_mc': 11080.79999999999, 'ucrl2': 24011.8}
# 2021-02-19 11:27:39.754654, Episode 620, cumulative total regret: {'ucrl2_mc': 11133.19999999999, 'ucrl2': 24250.0}
# 2021-02-19 11:28:14.609172, Episode 630, cumulative total regret: {'ucrl2_mc': 11220.89999999999, 'ucrl2': 24580.200000000004}
# 2021-02-19 11:28:49.535406, Episode 640, cumulative total regret: {'ucrl2_mc': 11308.099999999991, 'ucrl2': 24896.200000000004}
# 2021-02-19 11:29:24.082295, Episode 650, cumulative total regret: {'ucrl2_mc': 11366.999999999993, 'ucrl2': 25217.7}
# 2021-02-19 11:29:58.774228, Episode 660, cumulative total regret: {'ucrl2_mc': 11440.799999999994, 'ucrl2': 25480.200000000004}
# 2021-02-19 11:30:33.213711, Episode 670, cumulative total regret: {'ucrl2_mc': 11523.49999999999, 'ucrl2': 25843.100000000002}
# 2021-02-19 11:31:08.510413, Episode 680, cumulative total regret: {'ucrl2_mc': 11576.299999999992, 'ucrl2': 26076.0}
# 2021-02-19 11:31:42.544119, Episode 690, cumulative total regret: {'ucrl2_mc': 11589.799999999994, 'ucrl2': 26321.6}
# 2021-02-19 11:32:16.010804, Episode 700, cumulative total regret: {'ucrl2_mc': 11675.199999999995, 'ucrl2': 26650.399999999994}
# 2021-02-19 11:32:51.118353, Episode 710, cumulative total regret: {'ucrl2_mc': 11781.699999999995, 'ucrl2': 26995.099999999995}
# 2021-02-19 11:33:25.569596, Episode 720, cumulative total regret: {'ucrl2_mc': 11814.299999999996, 'ucrl2': 27295.499999999993}
# 2021-02-19 11:34:00.256829, Episode 730, cumulative total regret: {'ucrl2_mc': 11876.099999999997, 'ucrl2': 27572.299999999992}
# 2021-02-19 11:34:35.163934, Episode 740, cumulative total regret: {'ucrl2_mc': 11935.599999999995, 'ucrl2': 27826.899999999987}
# 2021-02-19 11:35:09.518911, Episode 750, cumulative total regret: {'ucrl2_mc': 12049.499999999993, 'ucrl2': 28164.899999999983}
# 2021-02-19 11:35:44.474667, Episode 760, cumulative total regret: {'ucrl2_mc': 12112.599999999991, 'ucrl2': 28457.499999999985}
# 2021-02-19 11:36:19.439573, Episode 770, cumulative total regret: {'ucrl2_mc': 12146.899999999992, 'ucrl2': 28761.799999999985}
# 2021-02-19 11:36:53.764068, Episode 780, cumulative total regret: {'ucrl2_mc': 12261.69999999999, 'ucrl2': 29127.499999999985}
# 2021-02-19 11:37:29.089292, Episode 790, cumulative total regret: {'ucrl2_mc': 12311.19999999999, 'ucrl2': 29328.399999999987}
# 2021-02-19 11:38:04.280072, Episode 800, cumulative total regret: {'ucrl2_mc': 12380.299999999988, 'ucrl2': 29589.799999999992}
# 2021-02-19 11:38:39.198374, Episode 810, cumulative total regret: {'ucrl2_mc': 12460.599999999991, 'ucrl2': 29809.199999999993}
# 2021-02-19 11:39:14.013082, Episode 820, cumulative total regret: {'ucrl2_mc': 12522.099999999991, 'ucrl2': 30041.899999999994}
# 2021-02-19 11:39:48.966628, Episode 830, cumulative total regret: {'ucrl2_mc': 12580.79999999999, 'ucrl2': 30281.1}
# 2021-02-19 11:40:23.929225, Episode 840, cumulative total regret: {'ucrl2_mc': 12622.29999999999, 'ucrl2': 30610.899999999998}
# 2021-02-19 11:40:59.092612, Episode 850, cumulative total regret: {'ucrl2_mc': 12691.599999999991, 'ucrl2': 30972.799999999992}
# 2021-02-19 11:41:33.216849, Episode 860, cumulative total regret: {'ucrl2_mc': 12783.899999999992, 'ucrl2': 31286.19999999999}
# 2021-02-19 11:42:08.221576, Episode 870, cumulative total regret: {'ucrl2_mc': 12835.49999999999, 'ucrl2': 31628.199999999986}
# 2021-02-19 11:42:43.159377, Episode 880, cumulative total regret: {'ucrl2_mc': 12836.599999999991, 'ucrl2': 31854.899999999987}
# 2021-02-19 11:43:18.744494, Episode 890, cumulative total regret: {'ucrl2_mc': 12893.199999999992, 'ucrl2': 32228.89999999999}
# 2021-02-19 11:43:53.779656, Episode 900, cumulative total regret: {'ucrl2_mc': 12946.999999999989, 'ucrl2': 32499.69999999999}
# 2021-02-19 11:44:28.582274, Episode 910, cumulative total regret: {'ucrl2_mc': 13067.999999999987, 'ucrl2': 32985.69999999999}
# 2021-02-19 11:45:04.132790, Episode 920, cumulative total regret: {'ucrl2_mc': 13111.399999999987, 'ucrl2': 33189.599999999984}
# 2021-02-19 11:45:38.784781, Episode 930, cumulative total regret: {'ucrl2_mc': 13208.799999999987, 'ucrl2': 33572.999999999985}
# 2021-02-19 11:46:13.588679, Episode 940, cumulative total regret: {'ucrl2_mc': 13226.899999999989, 'ucrl2': 33856.399999999994}
# 2021-02-19 11:46:48.952143, Episode 950, cumulative total regret: {'ucrl2_mc': 13286.299999999987, 'ucrl2': 34162.1}
# 2021-02-19 11:47:24.660819, Episode 960, cumulative total regret: {'ucrl2_mc': 13320.599999999986, 'ucrl2': 34444.40000000001}
# 2021-02-19 11:47:59.471890, Episode 970, cumulative total regret: {'ucrl2_mc': 13431.699999999984, 'ucrl2': 34820.299999999996}
# 2021-02-19 11:48:34.942882, Episode 980, cumulative total regret: {'ucrl2_mc': 13448.599999999982, 'ucrl2': 35015.49999999999}
# 2021-02-19 11:49:09.974120, Episode 990, cumulative total regret: {'ucrl2_mc': 13511.499999999982, 'ucrl2': 35261.29999999998}
# 2021-02-19 11:49:45.411667, Episode 1000, cumulative total regret: {'ucrl2_mc': 13578.899999999985, 'ucrl2': 35500.899999999994}
# 2021-02-19 11:50:20.709753, Episode 1010, cumulative total regret: {'ucrl2_mc': 13595.499999999984, 'ucrl2': 35705.99999999998}
# 2021-02-19 11:50:56.228301, Episode 1020, cumulative total regret: {'ucrl2_mc': 13645.299999999981, 'ucrl2': 35934.099999999984}
# 2021-02-19 11:51:31.992436, Episode 1030, cumulative total regret: {'ucrl2_mc': 13715.999999999982, 'ucrl2': 36126.599999999984}
# 2021-02-19 11:52:10.490883, Episode 1040, cumulative total regret: {'ucrl2_mc': 13771.599999999982, 'ucrl2': 36402.79999999999}
# 2021-02-19 11:52:46.986941, Episode 1050, cumulative total regret: {'ucrl2_mc': 13787.899999999983, 'ucrl2': 36572.699999999975}
# 2021-02-19 11:53:22.879348, Episode 1060, cumulative total regret: {'ucrl2_mc': 13773.999999999982, 'ucrl2': 36765.199999999975}
# 2021-02-19 11:53:58.356033, Episode 1070, cumulative total regret: {'ucrl2_mc': 13849.099999999984, 'ucrl2': 36959.29999999997}
# 2021-02-19 11:54:34.455708, Episode 1080, cumulative total regret: {'ucrl2_mc': 13892.399999999983, 'ucrl2': 37158.399999999965}
# 2021-02-19 11:55:10.260789, Episode 1090, cumulative total regret: {'ucrl2_mc': 13981.099999999982, 'ucrl2': 37414.499999999956}
# 2021-02-19 11:55:47.145152, Episode 1100, cumulative total regret: {'ucrl2_mc': 14029.69999999998, 'ucrl2': 37611.399999999965}
# 2021-02-19 11:56:23.414559, Episode 1110, cumulative total regret: {'ucrl2_mc': 14083.39999999998, 'ucrl2': 37750.899999999965}
# 2021-02-19 11:56:59.466390, Episode 1120, cumulative total regret: {'ucrl2_mc': 14115.299999999981, 'ucrl2': 38048.29999999996}
# 2021-02-19 11:57:35.458261, Episode 1130, cumulative total regret: {'ucrl2_mc': 14130.599999999979, 'ucrl2': 38294.19999999996}
# 2021-02-19 11:58:11.201716, Episode 1140, cumulative total regret: {'ucrl2_mc': 14122.699999999977, 'ucrl2': 38459.19999999995}
# 2021-02-19 11:58:47.943296, Episode 1150, cumulative total regret: {'ucrl2_mc': 14197.99999999998, 'ucrl2': 38701.79999999996}
# 2021-02-19 11:59:24.369387, Episode 1160, cumulative total regret: {'ucrl2_mc': 14196.99999999998, 'ucrl2': 38856.89999999997}
# 2021-02-19 12:00:00.653917, Episode 1170, cumulative total regret: {'ucrl2_mc': 14274.79999999998, 'ucrl2': 39140.89999999997}
# 2021-02-19 12:00:37.407271, Episode 1180, cumulative total regret: {'ucrl2_mc': 14314.79999999998, 'ucrl2': 39253.89999999998}
# 2021-02-19 12:01:13.849025, Episode 1190, cumulative total regret: {'ucrl2_mc': 14328.99999999998, 'ucrl2': 39416.09999999998}
# 2021-02-19 12:01:50.329775, Episode 1200, cumulative total regret: {'ucrl2_mc': 14388.09999999998, 'ucrl2': 39599.29999999997}
# 2021-02-19 12:02:26.230346, Episode 1210, cumulative total regret: {'ucrl2_mc': 14460.69999999998, 'ucrl2': 39896.899999999965}
# 2021-02-19 12:03:02.831169, Episode 1220, cumulative total regret: {'ucrl2_mc': 14473.999999999982, 'ucrl2': 40027.09999999996}
# 2021-02-19 12:03:39.422012, Episode 1230, cumulative total regret: {'ucrl2_mc': 14494.299999999981, 'ucrl2': 40215.29999999997}
# 2021-02-19 12:04:15.846170, Episode 1240, cumulative total regret: {'ucrl2_mc': 14540.49999999998, 'ucrl2': 40471.49999999996}
# 2021-02-19 12:04:52.351779, Episode 1250, cumulative total regret: {'ucrl2_mc': 14586.59999999998, 'ucrl2': 40586.79999999997}
# 2021-02-19 12:05:28.888087, Episode 1260, cumulative total regret: {'ucrl2_mc': 14607.799999999981, 'ucrl2': 40713.39999999996}
# 2021-02-19 12:06:05.432408, Episode 1270, cumulative total regret: {'ucrl2_mc': 14664.999999999982, 'ucrl2': 40918.39999999995}
# 2021-02-19 12:06:42.154734, Episode 1280, cumulative total regret: {'ucrl2_mc': 14657.999999999984, 'ucrl2': 41096.699999999946}
# 2021-02-19 12:07:18.441450, Episode 1290, cumulative total regret: {'ucrl2_mc': 14679.299999999987, 'ucrl2': 41246.29999999995}
# 2021-02-19 12:07:54.978159, Episode 1300, cumulative total regret: {'ucrl2_mc': 14707.799999999987, 'ucrl2': 41448.099999999955}
# 2021-02-19 12:08:31.475556, Episode 1310, cumulative total regret: {'ucrl2_mc': 14726.999999999989, 'ucrl2': 41545.299999999945}
# 2021-02-19 12:09:07.885528, Episode 1320, cumulative total regret: {'ucrl2_mc': 14772.19999999999, 'ucrl2': 41758.399999999936}
# 2021-02-19 12:09:44.920911, Episode 1330, cumulative total regret: {'ucrl2_mc': 14811.89999999999, 'ucrl2': 41884.49999999994}
# 2021-02-19 12:10:21.473596, Episode 1340, cumulative total regret: {'ucrl2_mc': 14866.49999999999, 'ucrl2': 42142.199999999946}
# 2021-02-19 12:10:58.351300, Episode 1350, cumulative total regret: {'ucrl2_mc': 14900.899999999992, 'ucrl2': 42271.79999999993}
# 2021-02-19 12:11:34.609448, Episode 1360, cumulative total regret: {'ucrl2_mc': 14984.199999999993, 'ucrl2': 42519.999999999935}
# 2021-02-19 12:12:11.528747, Episode 1370, cumulative total regret: {'ucrl2_mc': 15011.799999999994, 'ucrl2': 42686.59999999993}
# 2021-02-19 12:12:48.542300, Episode 1380, cumulative total regret: {'ucrl2_mc': 15043.999999999995, 'ucrl2': 42848.399999999936}
# 2021-02-19 12:13:25.374027, Episode 1390, cumulative total regret: {'ucrl2_mc': 15036.999999999993, 'ucrl2': 42908.99999999994}
# 2021-02-19 12:14:02.062348, Episode 1400, cumulative total regret: {'ucrl2_mc': 15053.699999999993, 'ucrl2': 43008.79999999994}
# 2021-02-19 12:14:38.242004, Episode 1410, cumulative total regret: {'ucrl2_mc': 15087.699999999992, 'ucrl2': 43207.09999999993}
# 2021-02-19 12:15:15.098103, Episode 1420, cumulative total regret: {'ucrl2_mc': 15140.399999999992, 'ucrl2': 43289.799999999945}
# 2021-02-19 12:15:52.371821, Episode 1430, cumulative total regret: {'ucrl2_mc': 15164.999999999995, 'ucrl2': 43518.69999999994}
# 2021-02-19 12:16:28.991180, Episode 1440, cumulative total regret: {'ucrl2_mc': 15211.899999999998, 'ucrl2': 43675.99999999994}
# 2021-02-19 12:17:05.712630, Episode 1450, cumulative total regret: {'ucrl2_mc': 15268.199999999997, 'ucrl2': 43846.89999999993}
# 2021-02-19 12:17:42.298958, Episode 1460, cumulative total regret: {'ucrl2_mc': 15369.799999999997, 'ucrl2': 43969.99999999993}
# 2021-02-19 12:18:19.078882, Episode 1470, cumulative total regret: {'ucrl2_mc': 15367.099999999995, 'ucrl2': 44070.39999999993}
# 2021-02-19 12:18:56.000776, Episode 1480, cumulative total regret: {'ucrl2_mc': 15437.699999999993, 'ucrl2': 44234.899999999936}
# 2021-02-19 12:19:32.597909, Episode 1490, cumulative total regret: {'ucrl2_mc': 15497.199999999993, 'ucrl2': 44336.69999999993}
# 2021-02-19 12:20:09.275997, Episode 1500, cumulative total regret: {'ucrl2_mc': 15534.299999999994, 'ucrl2': 44555.99999999992}
# 2021-02-19 12:20:46.108888, Episode 1510, cumulative total regret: {'ucrl2_mc': 15524.099999999993, 'ucrl2': 44604.99999999991}
# 2021-02-19 12:21:22.948732, Episode 1520, cumulative total regret: {'ucrl2_mc': 15552.199999999993, 'ucrl2': 44760.99999999991}
# 2021-02-19 12:21:59.708901, Episode 1530, cumulative total regret: {'ucrl2_mc': 15562.699999999993, 'ucrl2': 44817.899999999914}
# 2021-02-19 12:22:36.206392, Episode 1540, cumulative total regret: {'ucrl2_mc': 15570.499999999993, 'ucrl2': 44941.09999999992}
# 2021-02-19 12:23:12.341999, Episode 1550, cumulative total regret: {'ucrl2_mc': 15580.799999999994, 'ucrl2': 45089.899999999936}
# 2021-02-19 12:23:49.295857, Episode 1560, cumulative total regret: {'ucrl2_mc': 15585.999999999995, 'ucrl2': 45167.99999999994}
# 2021-02-19 12:24:26.544943, Episode 1570, cumulative total regret: {'ucrl2_mc': 15633.499999999995, 'ucrl2': 45308.79999999994}
# 2021-02-19 12:25:03.877663, Episode 1580, cumulative total regret: {'ucrl2_mc': 15660.599999999995, 'ucrl2': 45387.999999999935}
# 2021-02-19 12:25:40.663798, Episode 1590, cumulative total regret: {'ucrl2_mc': 15676.099999999993, 'ucrl2': 45507.999999999935}
# 2021-02-19 12:26:17.691073, Episode 1600, cumulative total regret: {'ucrl2_mc': 15705.899999999994, 'ucrl2': 45598.69999999993}
# 2021-02-19 12:26:54.450677, Episode 1610, cumulative total regret: {'ucrl2_mc': 15739.899999999994, 'ucrl2': 45721.69999999993}
# 2021-02-19 12:27:31.254388, Episode 1620, cumulative total regret: {'ucrl2_mc': 15759.099999999995, 'ucrl2': 45823.59999999993}
# 2021-02-19 12:28:08.612328, Episode 1630, cumulative total regret: {'ucrl2_mc': 15771.299999999997, 'ucrl2': 45927.39999999993}
# 2021-02-19 12:28:46.316564, Episode 1640, cumulative total regret: {'ucrl2_mc': 15800.899999999996, 'ucrl2': 46031.59999999993}
# 2021-02-19 12:29:23.083864, Episode 1650, cumulative total regret: {'ucrl2_mc': 15837.299999999996, 'ucrl2': 46139.59999999993}
# 2021-02-19 12:30:00.444390, Episode 1660, cumulative total regret: {'ucrl2_mc': 15874.799999999994, 'ucrl2': 46202.69999999994}
# 2021-02-19 12:30:37.224076, Episode 1670, cumulative total regret: {'ucrl2_mc': 15845.799999999994, 'ucrl2': 46268.49999999993}
# 2021-02-19 12:31:14.502263, Episode 1680, cumulative total regret: {'ucrl2_mc': 15870.099999999993, 'ucrl2': 46371.79999999992}
# 2021-02-19 12:31:51.584478, Episode 1690, cumulative total regret: {'ucrl2_mc': 15883.599999999995, 'ucrl2': 46429.49999999992}
# 2021-02-19 12:32:28.341776, Episode 1700, cumulative total regret: {'ucrl2_mc': 15898.599999999995, 'ucrl2': 46530.09999999991}
# 2021-02-19 12:33:05.197558, Episode 1710, cumulative total regret: {'ucrl2_mc': 15938.199999999995, 'ucrl2': 46624.19999999991}
# 2021-02-19 12:33:42.076434, Episode 1720, cumulative total regret: {'ucrl2_mc': 15980.099999999993, 'ucrl2': 46751.59999999991}
# 2021-02-19 12:34:19.360547, Episode 1730, cumulative total regret: {'ucrl2_mc': 15965.299999999992, 'ucrl2': 46816.399999999914}
# 2021-02-19 12:34:56.603688, Episode 1740, cumulative total regret: {'ucrl2_mc': 15996.399999999994, 'ucrl2': 46974.09999999992}
# 2021-02-19 12:35:33.642831, Episode 1750, cumulative total regret: {'ucrl2_mc': 16028.699999999995, 'ucrl2': 47038.69999999991}
# 2021-02-19 12:36:10.800546, Episode 1760, cumulative total regret: {'ucrl2_mc': 16103.399999999998, 'ucrl2': 47165.29999999991}
# 2021-02-19 12:36:48.690467, Episode 1770, cumulative total regret: {'ucrl2_mc': 16119.999999999998, 'ucrl2': 47304.19999999992}
# 2021-02-19 12:37:26.289232, Episode 1780, cumulative total regret: {'ucrl2_mc': 16159.9, 'ucrl2': 47426.59999999992}
# 2021-02-19 12:38:03.132727, Episode 1790, cumulative total regret: {'ucrl2_mc': 16164.1, 'ucrl2': 47541.99999999993}
# 2021-02-19 12:38:40.537985, Episode 1800, cumulative total regret: {'ucrl2_mc': 16170.7, 'ucrl2': 47652.49999999993}
# 2021-02-19 12:39:17.697138, Episode 1810, cumulative total regret: {'ucrl2_mc': 16196.500000000002, 'ucrl2': 47795.79999999994}
# 2021-02-19 12:39:54.470828, Episode 1820, cumulative total regret: {'ucrl2_mc': 16167.200000000003, 'ucrl2': 47886.69999999994}
# 2021-02-19 12:40:31.639251, Episode 1830, cumulative total regret: {'ucrl2_mc': 16212.300000000003, 'ucrl2': 47913.499999999935}
# 2021-02-19 12:41:08.689771, Episode 1840, cumulative total regret: {'ucrl2_mc': 16273.700000000003, 'ucrl2': 48009.19999999994}
# 2021-02-19 12:41:45.919906, Episode 1850, cumulative total regret: {'ucrl2_mc': 16269.100000000004, 'ucrl2': 48140.59999999994}
# 2021-02-19 12:42:23.547127, Episode 1860, cumulative total regret: {'ucrl2_mc': 16312.200000000006, 'ucrl2': 48264.09999999994}
# 2021-02-19 12:43:00.698571, Episode 1870, cumulative total regret: {'ucrl2_mc': 16359.400000000007, 'ucrl2': 48392.99999999994}
# 2021-02-19 12:43:37.908043, Episode 1880, cumulative total regret: {'ucrl2_mc': 16369.100000000008, 'ucrl2': 48477.79999999994}
# 2021-02-19 12:44:15.421748, Episode 1890, cumulative total regret: {'ucrl2_mc': 16433.500000000007, 'ucrl2': 48574.99999999994}
# 2021-02-19 12:44:52.145346, Episode 1900, cumulative total regret: {'ucrl2_mc': 16523.90000000001, 'ucrl2': 48670.399999999936}
# 2021-02-19 12:45:29.100587, Episode 1910, cumulative total regret: {'ucrl2_mc': 16561.200000000008, 'ucrl2': 48779.79999999993}
# 2021-02-19 12:46:05.930550, Episode 1920, cumulative total regret: {'ucrl2_mc': 16619.400000000012, 'ucrl2': 48900.89999999993}
# 2021-02-19 12:46:43.242593, Episode 1930, cumulative total regret: {'ucrl2_mc': 16652.20000000001, 'ucrl2': 48964.39999999994}
# 2021-02-19 12:47:20.434488, Episode 1940, cumulative total regret: {'ucrl2_mc': 16709.00000000001, 'ucrl2': 49055.39999999995}
# 2021-02-19 12:47:57.634232, Episode 1950, cumulative total regret: {'ucrl2_mc': 16752.800000000007, 'ucrl2': 49184.69999999995}
# 2021-02-19 12:48:34.603645, Episode 1960, cumulative total regret: {'ucrl2_mc': 16822.200000000008, 'ucrl2': 49290.49999999995}
# 2021-02-19 12:49:12.000505, Episode 1970, cumulative total regret: {'ucrl2_mc': 16825.700000000004, 'ucrl2': 49369.899999999965}
# 2021-02-19 12:49:49.316883, Episode 1980, cumulative total regret: {'ucrl2_mc': 16839.800000000003, 'ucrl2': 49429.09999999997}
# 2021-02-19 12:50:26.391092, Episode 1990, cumulative total regret: {'ucrl2_mc': 16898.699999999997, 'ucrl2': 49567.39999999997}
# 2021-02-19 12:51:03.604190, Episode 2000, cumulative total regret: {'ucrl2_mc': 16905.59999999999, 'ucrl2': 49663.89999999997}
# 2021-02-19 12:51:40.488240, Episode 2010, cumulative total regret: {'ucrl2_mc': 16968.5, 'ucrl2': 49731.89999999998}
# 2021-02-19 12:52:17.481057, Episode 2020, cumulative total regret: {'ucrl2_mc': 16998.700000000004, 'ucrl2': 49844.99999999998}
# 2021-02-19 12:52:54.936471, Episode 2030, cumulative total regret: {'ucrl2_mc': 16981.900000000005, 'ucrl2': 49838.29999999998}
# 2021-02-19 12:53:32.363837, Episode 2040, cumulative total regret: {'ucrl2_mc': 17025.40000000001, 'ucrl2': 49911.89999999997}
# 2021-02-19 12:54:09.673832, Episode 2050, cumulative total regret: {'ucrl2_mc': 17030.300000000007, 'ucrl2': 49952.59999999997}
# 2021-02-19 12:54:46.451667, Episode 2060, cumulative total regret: {'ucrl2_mc': 17103.100000000006, 'ucrl2': 50017.69999999997}
# 2021-02-19 12:55:23.265143, Episode 2070, cumulative total regret: {'ucrl2_mc': 17149.400000000005, 'ucrl2': 50107.299999999974}
# 2021-02-19 12:56:00.348906, Episode 2080, cumulative total regret: {'ucrl2_mc': 17190.100000000002, 'ucrl2': 50203.89999999997}
# 2021-02-19 12:56:37.094519, Episode 2090, cumulative total regret: {'ucrl2_mc': 17240.600000000006, 'ucrl2': 50261.899999999965}
# 2021-02-19 12:57:14.332036, Episode 2100, cumulative total regret: {'ucrl2_mc': 17320.200000000004, 'ucrl2': 50322.39999999997}
# 2021-02-19 12:57:51.504813, Episode 2110, cumulative total regret: {'ucrl2_mc': 17318.0, 'ucrl2': 50390.29999999997}
# 2021-02-19 12:58:29.036720, Episode 2120, cumulative total regret: {'ucrl2_mc': 17340.4, 'ucrl2': 50439.79999999997}
# 2021-02-19 12:59:06.006951, Episode 2130, cumulative total regret: {'ucrl2_mc': 17372.7, 'ucrl2': 50527.39999999997}
# 2021-02-19 12:59:42.869547, Episode 2140, cumulative total regret: {'ucrl2_mc': 17387.600000000002, 'ucrl2': 50584.09999999997}
# 2021-02-19 13:00:19.801495, Episode 2150, cumulative total regret: {'ucrl2_mc': 17400.90000000001, 'ucrl2': 50658.19999999997}
# 2021-02-19 13:00:57.359727, Episode 2160, cumulative total regret: {'ucrl2_mc': 17456.800000000007, 'ucrl2': 50711.79999999996}
# 2021-02-19 13:01:34.645324, Episode 2170, cumulative total regret: {'ucrl2_mc': 17469.100000000013, 'ucrl2': 50726.29999999997}
# 2021-02-19 13:02:11.668227, Episode 2180, cumulative total regret: {'ucrl2_mc': 17508.70000000001, 'ucrl2': 50805.799999999974}
# 2021-02-19 13:02:48.888207, Episode 2190, cumulative total regret: {'ucrl2_mc': 17511.90000000001, 'ucrl2': 50874.69999999998}
# 2021-02-19 13:03:26.143120, Episode 2200, cumulative total regret: {'ucrl2_mc': 17512.50000000001, 'ucrl2': 50919.59999999997}
# 2021-02-19 13:04:03.853777, Episode 2210, cumulative total regret: {'ucrl2_mc': 17547.80000000001, 'ucrl2': 50952.69999999997}
# 2021-02-19 13:04:40.873055, Episode 2220, cumulative total regret: {'ucrl2_mc': 17571.000000000004, 'ucrl2': 51078.59999999997}
# 2021-02-19 13:05:18.242813, Episode 2230, cumulative total regret: {'ucrl2_mc': 17577.599999999995, 'ucrl2': 51115.29999999996}
# 2021-02-19 13:05:55.306567, Episode 2240, cumulative total regret: {'ucrl2_mc': 17618.599999999995, 'ucrl2': 51252.999999999956}
# 2021-02-19 13:06:32.536576, Episode 2250, cumulative total regret: {'ucrl2_mc': 17664.5, 'ucrl2': 51327.59999999996}
# 2021-02-19 13:07:10.012070, Episode 2260, cumulative total regret: {'ucrl2_mc': 17699.1, 'ucrl2': 51386.29999999996}
# 2021-02-19 13:07:47.093591, Episode 2270, cumulative total regret: {'ucrl2_mc': 17731.199999999997, 'ucrl2': 51455.599999999955}
# 2021-02-19 13:08:23.923726, Episode 2280, cumulative total regret: {'ucrl2_mc': 17784.399999999998, 'ucrl2': 51549.99999999996}
# 2021-02-19 13:09:01.168631, Episode 2290, cumulative total regret: {'ucrl2_mc': 17831.899999999998, 'ucrl2': 51599.29999999997}
# 2021-02-19 13:09:38.847719, Episode 2300, cumulative total regret: {'ucrl2_mc': 17842.399999999998, 'ucrl2': 51688.29999999997}
# 2021-02-19 13:10:15.926587, Episode 2310, cumulative total regret: {'ucrl2_mc': 17899.399999999994, 'ucrl2': 51814.99999999996}
# 2021-02-19 13:10:53.124903, Episode 2320, cumulative total regret: {'ucrl2_mc': 17954.899999999994, 'ucrl2': 51896.69999999996}
# 2021-02-19 13:11:30.368202, Episode 2330, cumulative total regret: {'ucrl2_mc': 17955.499999999996, 'ucrl2': 51965.499999999956}
# 2021-02-19 13:12:07.566322, Episode 2340, cumulative total regret: {'ucrl2_mc': 17960.299999999992, 'ucrl2': 52045.899999999965}
# 2021-02-19 13:12:44.946004, Episode 2350, cumulative total regret: {'ucrl2_mc': 17982.09999999999, 'ucrl2': 52139.999999999956}
# 2021-02-19 13:13:22.214897, Episode 2360, cumulative total regret: {'ucrl2_mc': 17956.99999999999, 'ucrl2': 52202.49999999996}
# 2021-02-19 13:13:59.553693, Episode 2370, cumulative total regret: {'ucrl2_mc': 17984.29999999999, 'ucrl2': 52278.89999999997}
# 2021-02-19 13:14:36.817127, Episode 2380, cumulative total regret: {'ucrl2_mc': 17966.599999999988, 'ucrl2': 52391.79999999998}
# 2021-02-19 13:15:14.218802, Episode 2390, cumulative total regret: {'ucrl2_mc': 18011.799999999985, 'ucrl2': 52450.89999999997}
# 2021-02-19 13:15:51.550065, Episode 2400, cumulative total regret: {'ucrl2_mc': 17973.699999999983, 'ucrl2': 52515.09999999996}
# 2021-02-19 13:16:28.760024, Episode 2410, cumulative total regret: {'ucrl2_mc': 17975.599999999984, 'ucrl2': 52560.999999999956}
# 2021-02-19 13:17:06.305777, Episode 2420, cumulative total regret: {'ucrl2_mc': 18019.899999999987, 'ucrl2': 52629.49999999996}
# 2021-02-19 13:17:43.533263, Episode 2430, cumulative total regret: {'ucrl2_mc': 18063.09999999999, 'ucrl2': 52736.09999999996}
# 2021-02-19 13:18:20.963231, Episode 2440, cumulative total regret: {'ucrl2_mc': 18047.099999999988, 'ucrl2': 52793.29999999996}
# 2021-02-19 13:18:58.372137, Episode 2450, cumulative total regret: {'ucrl2_mc': 18111.399999999987, 'ucrl2': 52910.79999999997}
# 2021-02-19 13:19:35.713260, Episode 2460, cumulative total regret: {'ucrl2_mc': 18136.19999999999, 'ucrl2': 52938.49999999998}
# 2021-02-19 13:20:13.204298, Episode 2470, cumulative total regret: {'ucrl2_mc': 18120.89999999999, 'ucrl2': 52964.49999999998}
# 2021-02-19 13:20:50.540194, Episode 2480, cumulative total regret: {'ucrl2_mc': 18130.399999999987, 'ucrl2': 53037.69999999999}
# 2021-02-19 13:21:27.634762, Episode 2490, cumulative total regret: {'ucrl2_mc': 18147.199999999986, 'ucrl2': 53150.29999999999}
# 2021-02-19 13:22:05.082312, Episode 2500, cumulative total regret: {'ucrl2_mc': 18150.599999999988, 'ucrl2': 53185.0}
# 2021-02-19 13:22:42.019257, Episode 2510, cumulative total regret: {'ucrl2_mc': 18164.69999999999, 'ucrl2': 53247.69999999999}
# 2021-02-19 13:23:18.794329, Episode 2520, cumulative total regret: {'ucrl2_mc': 18176.69999999999, 'ucrl2': 53294.399999999994}
# 2021-02-19 13:23:55.763206, Episode 2530, cumulative total regret: {'ucrl2_mc': 18190.79999999999, 'ucrl2': 53315.90000000001}
# 2021-02-19 13:24:32.739437, Episode 2540, cumulative total regret: {'ucrl2_mc': 18195.499999999993, 'ucrl2': 53282.8}
# 2021-02-19 13:25:09.885461, Episode 2550, cumulative total regret: {'ucrl2_mc': 18206.399999999994, 'ucrl2': 53316.4}
# 2021-02-19 13:25:46.949364, Episode 2560, cumulative total regret: {'ucrl2_mc': 18209.799999999992, 'ucrl2': 53326.7}
# 2021-02-19 13:26:24.045680, Episode 2570, cumulative total regret: {'ucrl2_mc': 18232.099999999988, 'ucrl2': 53314.299999999996}
# 2021-02-19 13:27:01.408255, Episode 2580, cumulative total regret: {'ucrl2_mc': 18257.999999999993, 'ucrl2': 53308.9}
# 2021-02-19 13:27:38.720660, Episode 2590, cumulative total regret: {'ucrl2_mc': 18315.099999999995, 'ucrl2': 53348.100000000006}
# 2021-02-19 13:28:15.609532, Episode 2600, cumulative total regret: {'ucrl2_mc': 18333.299999999992, 'ucrl2': 53393.799999999996}
# 2021-02-19 13:28:52.847663, Episode 2610, cumulative total regret: {'ucrl2_mc': 18323.999999999993, 'ucrl2': 53413.2}
# 2021-02-19 13:29:29.787280, Episode 2620, cumulative total regret: {'ucrl2_mc': 18335.499999999993, 'ucrl2': 53483.000000000015}
# 2021-02-19 13:30:06.997626, Episode 2630, cumulative total regret: {'ucrl2_mc': 18359.799999999996, 'ucrl2': 53537.700000000026}
# 2021-02-19 13:30:44.644119, Episode 2640, cumulative total regret: {'ucrl2_mc': 18386.699999999993, 'ucrl2': 53588.50000000002}
# 2021-02-19 13:31:21.958250, Episode 2650, cumulative total regret: {'ucrl2_mc': 18430.0, 'ucrl2': 53635.200000000026}
# 2021-02-19 13:31:59.939007, Episode 2660, cumulative total regret: {'ucrl2_mc': 18489.899999999994, 'ucrl2': 53723.60000000003}
# 2021-02-19 13:32:37.539484, Episode 2670, cumulative total regret: {'ucrl2_mc': 18507.299999999996, 'ucrl2': 53758.00000000004}
# 2021-02-19 13:33:14.858299, Episode 2680, cumulative total regret: {'ucrl2_mc': 18526.499999999996, 'ucrl2': 53811.80000000004}
# 2021-02-19 13:33:52.469225, Episode 2690, cumulative total regret: {'ucrl2_mc': 18546.899999999998, 'ucrl2': 53854.40000000003}
# 2021-02-19 13:34:30.193008, Episode 2700, cumulative total regret: {'ucrl2_mc': 18567.899999999994, 'ucrl2': 53892.60000000004}
# 2021-02-19 13:35:07.065043, Episode 2710, cumulative total regret: {'ucrl2_mc': 18568.59999999999, 'ucrl2': 53965.80000000004}
# 2021-02-19 13:35:44.804072, Episode 2720, cumulative total regret: {'ucrl2_mc': 18621.199999999993, 'ucrl2': 53997.30000000004}
# 2021-02-19 13:36:22.299460, Episode 2730, cumulative total regret: {'ucrl2_mc': 18645.699999999993, 'ucrl2': 54024.20000000003}
# 2021-02-19 13:36:59.914557, Episode 2740, cumulative total regret: {'ucrl2_mc': 18701.699999999993, 'ucrl2': 54100.40000000003}
# 2021-02-19 13:37:36.776281, Episode 2750, cumulative total regret: {'ucrl2_mc': 18751.199999999993, 'ucrl2': 54168.20000000004}
# 2021-02-19 13:38:13.899821, Episode 2760, cumulative total regret: {'ucrl2_mc': 18750.099999999988, 'ucrl2': 54211.10000000005}
# 2021-02-19 13:38:51.648438, Episode 2770, cumulative total regret: {'ucrl2_mc': 18801.79999999999, 'ucrl2': 54238.800000000054}
# 2021-02-19 13:39:28.690248, Episode 2780, cumulative total regret: {'ucrl2_mc': 18804.39999999999, 'ucrl2': 54276.30000000006}
# 2021-02-19 13:40:06.056303, Episode 2790, cumulative total regret: {'ucrl2_mc': 18831.69999999999, 'ucrl2': 54329.500000000065}
# 2021-02-19 13:40:43.565810, Episode 2800, cumulative total regret: {'ucrl2_mc': 18832.19999999999, 'ucrl2': 54357.10000000006}
# 2021-02-19 13:41:20.858354, Episode 2810, cumulative total regret: {'ucrl2_mc': 18867.999999999993, 'ucrl2': 54419.70000000005}
# 2021-02-19 13:41:58.691308, Episode 2820, cumulative total regret: {'ucrl2_mc': 18905.499999999993, 'ucrl2': 54460.000000000044}
# 2021-02-19 13:42:35.511843, Episode 2830, cumulative total regret: {'ucrl2_mc': 18922.29999999999, 'ucrl2': 54495.40000000004}
# 2021-02-19 13:43:12.717194, Episode 2840, cumulative total regret: {'ucrl2_mc': 18961.09999999999, 'ucrl2': 54520.30000000004}
# 2021-02-19 13:43:50.232482, Episode 2850, cumulative total regret: {'ucrl2_mc': 18944.499999999996, 'ucrl2': 54532.40000000004}
# 2021-02-19 13:44:27.817299, Episode 2860, cumulative total regret: {'ucrl2_mc': 18959.199999999997, 'ucrl2': 54532.60000000004}
# 2021-02-19 13:45:05.395719, Episode 2870, cumulative total regret: {'ucrl2_mc': 18981.499999999993, 'ucrl2': 54592.400000000045}
# 2021-02-19 13:45:42.632698, Episode 2880, cumulative total regret: {'ucrl2_mc': 19001.89999999999, 'ucrl2': 54615.60000000005}
# 2021-02-19 13:46:20.009102, Episode 2890, cumulative total regret: {'ucrl2_mc': 19017.699999999993, 'ucrl2': 54642.00000000006}
# 2021-02-19 13:46:57.562527, Episode 2900, cumulative total regret: {'ucrl2_mc': 19015.299999999996, 'ucrl2': 54692.90000000005}
# 2021-02-19 13:47:34.616984, Episode 2910, cumulative total regret: {'ucrl2_mc': 18988.699999999993, 'ucrl2': 54727.20000000007}
# 2021-02-19 13:48:12.302953, Episode 2920, cumulative total regret: {'ucrl2_mc': 18990.099999999995, 'ucrl2': 54757.20000000006}
# 2021-02-19 13:48:49.546462, Episode 2930, cumulative total regret: {'ucrl2_mc': 19010.199999999997, 'ucrl2': 54813.60000000007}
# 2021-02-19 13:49:27.515051, Episode 2940, cumulative total regret: {'ucrl2_mc': 19032.399999999994, 'ucrl2': 54853.20000000006}
# 2021-02-19 13:50:05.151748, Episode 2950, cumulative total regret: {'ucrl2_mc': 19046.299999999996, 'ucrl2': 54904.600000000064}
# 2021-02-19 13:50:42.612830, Episode 2960, cumulative total regret: {'ucrl2_mc': 19051.599999999995, 'ucrl2': 54945.50000000007}
# 2021-02-19 13:51:20.143753, Episode 2970, cumulative total regret: {'ucrl2_mc': 19093.199999999993, 'ucrl2': 54991.40000000008}
# 2021-02-19 13:51:57.762534, Episode 2980, cumulative total regret: {'ucrl2_mc': 19139.099999999995, 'ucrl2': 55087.30000000009}
# 2021-02-19 13:52:35.657596, Episode 2990, cumulative total regret: {'ucrl2_mc': 19170.6, 'ucrl2': 55148.50000000007}
# 2021-02-19 13:53:13.814727, Episode 3000, cumulative total regret: {'ucrl2_mc': 19162.999999999996, 'ucrl2': 55151.20000000007}
# 2021-02-19 13:53:50.510685, Episode 3010, cumulative total regret: {'ucrl2_mc': 19180.799999999992, 'ucrl2': 55186.900000000074}
# 2021-02-19 13:54:27.888985, Episode 3020, cumulative total regret: {'ucrl2_mc': 19215.699999999997, 'ucrl2': 55243.900000000074}
# 2021-02-19 13:55:04.858086, Episode 3030, cumulative total regret: {'ucrl2_mc': 19225.4, 'ucrl2': 55256.700000000084}
# 2021-02-19 13:55:41.777778, Episode 3040, cumulative total regret: {'ucrl2_mc': 19215.600000000002, 'ucrl2': 55233.200000000084}
# 2021-02-19 13:56:18.875586, Episode 3050, cumulative total regret: {'ucrl2_mc': 19252.500000000004, 'ucrl2': 55268.200000000084}
# 2021-02-19 13:56:56.426259, Episode 3060, cumulative total regret: {'ucrl2_mc': 19273.9, 'ucrl2': 55369.900000000074}
# 2021-02-19 13:57:33.514117, Episode 3070, cumulative total regret: {'ucrl2_mc': 19266.9, 'ucrl2': 55385.400000000074}
# 2021-02-19 13:58:10.591405, Episode 3080, cumulative total regret: {'ucrl2_mc': 19314.100000000002, 'ucrl2': 55403.600000000086}
# 2021-02-19 13:58:48.208445, Episode 3090, cumulative total regret: {'ucrl2_mc': 19350.600000000006, 'ucrl2': 55428.400000000096}
# 2021-02-19 13:59:25.031217, Episode 3100, cumulative total regret: {'ucrl2_mc': 19357.400000000005, 'ucrl2': 55497.6000000001}
# 2021-02-19 14:00:02.829454, Episode 3110, cumulative total regret: {'ucrl2_mc': 19410.200000000008, 'ucrl2': 55514.900000000096}
# 2021-02-19 14:00:40.287781, Episode 3120, cumulative total regret: {'ucrl2_mc': 19415.400000000012, 'ucrl2': 55545.50000000009}
# 2021-02-19 14:01:17.593248, Episode 3130, cumulative total regret: {'ucrl2_mc': 19435.50000000001, 'ucrl2': 55547.00000000009}
# 2021-02-19 14:01:54.945421, Episode 3140, cumulative total regret: {'ucrl2_mc': 19458.70000000001, 'ucrl2': 55549.700000000084}
# 2021-02-19 14:02:32.498645, Episode 3150, cumulative total regret: {'ucrl2_mc': 19512.30000000001, 'ucrl2': 55615.30000000008}
# 2021-02-19 14:03:10.441670, Episode 3160, cumulative total regret: {'ucrl2_mc': 19542.000000000007, 'ucrl2': 55643.300000000076}
# 2021-02-19 14:03:47.482913, Episode 3170, cumulative total regret: {'ucrl2_mc': 19597.700000000004, 'ucrl2': 55706.10000000007}
# 2021-02-19 14:04:24.966903, Episode 3180, cumulative total regret: {'ucrl2_mc': 19614.10000000001, 'ucrl2': 55750.30000000006}
# 2021-02-19 14:05:02.333276, Episode 3190, cumulative total regret: {'ucrl2_mc': 19667.400000000016, 'ucrl2': 55799.80000000006}
# 2021-02-19 14:05:39.780597, Episode 3200, cumulative total regret: {'ucrl2_mc': 19708.90000000002, 'ucrl2': 55844.90000000005}
# 2021-02-19 14:06:16.776597, Episode 3210, cumulative total regret: {'ucrl2_mc': 19737.10000000002, 'ucrl2': 55883.900000000045}
# 2021-02-19 14:06:53.947821, Episode 3220, cumulative total regret: {'ucrl2_mc': 19771.70000000002, 'ucrl2': 55936.30000000005}
# 2021-02-19 14:07:31.548214, Episode 3230, cumulative total regret: {'ucrl2_mc': 19814.100000000017, 'ucrl2': 55953.60000000004}
# 2021-02-19 14:08:08.905835, Episode 3240, cumulative total regret: {'ucrl2_mc': 19837.300000000017, 'ucrl2': 56011.70000000004}
# 2021-02-19 14:08:46.416485, Episode 3250, cumulative total regret: {'ucrl2_mc': 19864.500000000015, 'ucrl2': 56053.90000000004}
# 2021-02-19 14:09:23.771309, Episode 3260, cumulative total regret: {'ucrl2_mc': 19899.900000000016, 'ucrl2': 56085.10000000003}
# 2021-02-19 14:10:00.668810, Episode 3270, cumulative total regret: {'ucrl2_mc': 19954.800000000014, 'ucrl2': 56115.20000000003}
# 2021-02-19 14:10:37.873527, Episode 3280, cumulative total regret: {'ucrl2_mc': 19987.600000000013, 'ucrl2': 56145.20000000004}
# 2021-02-19 14:11:16.076788, Episode 3290, cumulative total regret: {'ucrl2_mc': 20017.60000000001, 'ucrl2': 56148.50000000004}
# 2021-02-19 14:11:53.907663, Episode 3300, cumulative total regret: {'ucrl2_mc': 20030.00000000001, 'ucrl2': 56231.20000000004}
# 2021-02-19 14:12:31.434620, Episode 3310, cumulative total regret: {'ucrl2_mc': 20043.400000000012, 'ucrl2': 56275.50000000005}
# 2021-02-19 14:13:08.719844, Episode 3320, cumulative total regret: {'ucrl2_mc': 20096.500000000015, 'ucrl2': 56303.10000000006}
# 2021-02-19 14:13:46.206136, Episode 3330, cumulative total regret: {'ucrl2_mc': 20167.500000000015, 'ucrl2': 56355.200000000055}
# 2021-02-19 14:14:23.658998, Episode 3340, cumulative total regret: {'ucrl2_mc': 20203.000000000015, 'ucrl2': 56366.20000000006}
# 2021-02-19 14:15:01.331515, Episode 3350, cumulative total regret: {'ucrl2_mc': 20213.400000000012, 'ucrl2': 56417.40000000007}
# 2021-02-19 14:15:39.716051, Episode 3360, cumulative total regret: {'ucrl2_mc': 20265.50000000001, 'ucrl2': 56455.30000000007}
# 2021-02-19 14:16:18.039026, Episode 3370, cumulative total regret: {'ucrl2_mc': 20265.400000000012, 'ucrl2': 56460.600000000064}
# 2021-02-19 14:16:55.984430, Episode 3380, cumulative total regret: {'ucrl2_mc': 20289.700000000015, 'ucrl2': 56493.600000000064}
# 2021-02-19 14:17:33.797677, Episode 3390, cumulative total regret: {'ucrl2_mc': 20325.40000000001, 'ucrl2': 56509.90000000006}
# 2021-02-19 14:18:11.533671, Episode 3400, cumulative total regret: {'ucrl2_mc': 20367.200000000008, 'ucrl2': 56562.100000000064}
# 2021-02-19 14:18:49.060883, Episode 3410, cumulative total regret: {'ucrl2_mc': 20354.10000000001, 'ucrl2': 56582.30000000006}
# 2021-02-19 14:19:26.763363, Episode 3420, cumulative total regret: {'ucrl2_mc': 20379.90000000001, 'ucrl2': 56636.40000000006}
# 2021-02-19 14:20:04.571300, Episode 3430, cumulative total regret: {'ucrl2_mc': 20440.600000000006, 'ucrl2': 56685.700000000055}
# 2021-02-19 14:20:42.201772, Episode 3440, cumulative total regret: {'ucrl2_mc': 20450.400000000005, 'ucrl2': 56740.30000000005}
# 2021-02-19 14:21:19.923313, Episode 3450, cumulative total regret: {'ucrl2_mc': 20452.9, 'ucrl2': 56724.90000000005}
# 2021-02-19 14:21:57.934614, Episode 3460, cumulative total regret: {'ucrl2_mc': 20462.5, 'ucrl2': 56757.30000000006}
# 2021-02-19 14:22:35.478110, Episode 3470, cumulative total regret: {'ucrl2_mc': 20487.399999999998, 'ucrl2': 56777.70000000008}
# 2021-02-19 14:23:12.904772, Episode 3480, cumulative total regret: {'ucrl2_mc': 20518.299999999996, 'ucrl2': 56851.90000000008}
# 2021-02-19 14:23:50.679763, Episode 3490, cumulative total regret: {'ucrl2_mc': 20553.899999999998, 'ucrl2': 56889.80000000008}
# 2021-02-19 14:24:29.411912, Episode 3500, cumulative total regret: {'ucrl2_mc': 20588.4, 'ucrl2': 56887.700000000084}
# 2021-02-19 14:25:16.130058, Episode 3510, cumulative total regret: {'ucrl2_mc': 20602.300000000003, 'ucrl2': 56920.90000000008}
# 2021-02-19 14:26:02.164909, Episode 3520, cumulative total regret: {'ucrl2_mc': 20585.399999999998, 'ucrl2': 56941.30000000008}
# 2021-02-19 14:26:48.831165, Episode 3530, cumulative total regret: {'ucrl2_mc': 20586.399999999994, 'ucrl2': 56964.300000000076}
# 2021-02-19 14:27:35.699236, Episode 3540, cumulative total regret: {'ucrl2_mc': 20607.099999999995, 'ucrl2': 56978.00000000008}
# 2021-02-19 14:28:22.658013, Episode 3550, cumulative total regret: {'ucrl2_mc': 20637.699999999997, 'ucrl2': 56990.70000000008}
# 2021-02-19 14:29:09.075271, Episode 3560, cumulative total regret: {'ucrl2_mc': 20623.599999999995, 'ucrl2': 56987.400000000074}
# 2021-02-19 14:29:55.845471, Episode 3570, cumulative total regret: {'ucrl2_mc': 20659.399999999987, 'ucrl2': 56985.40000000008}
# 2021-02-19 14:30:43.199489, Episode 3580, cumulative total regret: {'ucrl2_mc': 20662.99999999999, 'ucrl2': 57010.90000000009}
# 2021-02-19 14:31:29.578168, Episode 3590, cumulative total regret: {'ucrl2_mc': 20703.799999999992, 'ucrl2': 57026.00000000007}
# 2021-02-19 14:32:16.372459, Episode 3600, cumulative total regret: {'ucrl2_mc': 20731.199999999993, 'ucrl2': 57045.900000000074}
# 2021-02-19 14:33:03.262426, Episode 3610, cumulative total regret: {'ucrl2_mc': 20775.399999999998, 'ucrl2': 57050.900000000074}
# 2021-02-19 14:33:50.965085, Episode 3620, cumulative total regret: {'ucrl2_mc': 20816.399999999998, 'ucrl2': 57091.80000000007}
# 2021-02-19 14:34:37.674957, Episode 3630, cumulative total regret: {'ucrl2_mc': 20839.299999999996, 'ucrl2': 57125.400000000074}
# 2021-02-19 14:35:23.876704, Episode 3640, cumulative total regret: {'ucrl2_mc': 20840.999999999996, 'ucrl2': 57142.90000000008}
# 2021-02-19 14:36:10.749836, Episode 3650, cumulative total regret: {'ucrl2_mc': 20836.599999999995, 'ucrl2': 57123.60000000009}
# 2021-02-19 14:36:56.296753, Episode 3660, cumulative total regret: {'ucrl2_mc': 20884.7, 'ucrl2': 57147.400000000096}
# 2021-02-19 14:37:43.401912, Episode 3670, cumulative total regret: {'ucrl2_mc': 20901.800000000003, 'ucrl2': 57163.000000000095}
# 2021-02-19 14:38:30.536008, Episode 3680, cumulative total regret: {'ucrl2_mc': 20922.700000000008, 'ucrl2': 57185.000000000095}
# 2021-02-19 14:39:17.977426, Episode 3690, cumulative total regret: {'ucrl2_mc': 20992.000000000004, 'ucrl2': 57229.2000000001}
# 2021-02-19 14:40:04.980592, Episode 3700, cumulative total regret: {'ucrl2_mc': 21030.100000000002, 'ucrl2': 57303.000000000095}
# 2021-02-19 14:40:51.130372, Episode 3710, cumulative total regret: {'ucrl2_mc': 21021.800000000007, 'ucrl2': 57295.9000000001}
# 2021-02-19 14:41:36.976750, Episode 3720, cumulative total regret: {'ucrl2_mc': 21048.300000000003, 'ucrl2': 57331.300000000105}
# 2021-02-19 14:42:23.145801, Episode 3730, cumulative total regret: {'ucrl2_mc': 21080.500000000004, 'ucrl2': 57326.60000000009}
# 2021-02-19 14:43:09.717691, Episode 3740, cumulative total regret: {'ucrl2_mc': 21122.3, 'ucrl2': 57350.4000000001}
# 2021-02-19 14:43:55.843086, Episode 3750, cumulative total regret: {'ucrl2_mc': 21141.899999999998, 'ucrl2': 57391.9000000001}
# 2021-02-19 14:44:40.801421, Episode 3760, cumulative total regret: {'ucrl2_mc': 21143.999999999993, 'ucrl2': 57411.60000000009}
# 2021-02-19 14:45:27.269873, Episode 3770, cumulative total regret: {'ucrl2_mc': 21185.699999999993, 'ucrl2': 57408.10000000009}
# 2021-02-19 14:46:14.304406, Episode 3780, cumulative total regret: {'ucrl2_mc': 21219.39999999999, 'ucrl2': 57412.900000000096}
# 2021-02-19 14:46:59.525633, Episode 3790, cumulative total regret: {'ucrl2_mc': 21221.99999999999, 'ucrl2': 57426.200000000084}
# 2021-02-19 14:47:46.241140, Episode 3800, cumulative total regret: {'ucrl2_mc': 21254.09999999999, 'ucrl2': 57423.00000000009}
# 2021-02-19 14:48:33.395876, Episode 3810, cumulative total regret: {'ucrl2_mc': 21275.999999999993, 'ucrl2': 57469.40000000008}
# 2021-02-19 14:49:19.660472, Episode 3820, cumulative total regret: {'ucrl2_mc': 21296.099999999988, 'ucrl2': 57514.50000000009}
# 2021-02-19 14:50:04.728526, Episode 3830, cumulative total regret: {'ucrl2_mc': 21331.59999999999, 'ucrl2': 57524.700000000084}
# 2021-02-19 14:50:50.662088, Episode 3840, cumulative total regret: {'ucrl2_mc': 21389.199999999993, 'ucrl2': 57566.700000000084}
# 2021-02-19 14:51:37.157506, Episode 3850, cumulative total regret: {'ucrl2_mc': 21387.39999999999, 'ucrl2': 57576.600000000086}
# 2021-02-19 14:52:23.623580, Episode 3860, cumulative total regret: {'ucrl2_mc': 21404.89999999999, 'ucrl2': 57612.10000000009}
# 2021-02-19 14:53:09.550970, Episode 3870, cumulative total regret: {'ucrl2_mc': 21426.999999999993, 'ucrl2': 57601.7000000001}
# 2021-02-19 14:53:54.957438, Episode 3880, cumulative total regret: {'ucrl2_mc': 21413.19999999999, 'ucrl2': 57610.90000000009}
# 2021-02-19 14:54:41.761090, Episode 3890, cumulative total regret: {'ucrl2_mc': 21455.699999999983, 'ucrl2': 57648.10000000008}
# 2021-02-19 14:55:28.329253, Episode 3900, cumulative total regret: {'ucrl2_mc': 21459.799999999985, 'ucrl2': 57637.000000000095}
# 2021-02-19 14:56:14.765611, Episode 3910, cumulative total regret: {'ucrl2_mc': 21468.299999999985, 'ucrl2': 57618.600000000086}
# 2021-02-19 14:57:01.753456, Episode 3920, cumulative total regret: {'ucrl2_mc': 21513.59999999998, 'ucrl2': 57650.50000000009}
# 2021-02-19 14:57:47.385548, Episode 3930, cumulative total regret: {'ucrl2_mc': 21528.899999999983, 'ucrl2': 57679.30000000009}
# 2021-02-19 14:58:33.628117, Episode 3940, cumulative total regret: {'ucrl2_mc': 21544.099999999984, 'ucrl2': 57684.40000000009}
# 2021-02-19 14:59:19.991210, Episode 3950, cumulative total regret: {'ucrl2_mc': 21578.99999999998, 'ucrl2': 57717.900000000074}
# 2021-02-19 15:00:06.901493, Episode 3960, cumulative total regret: {'ucrl2_mc': 21637.69999999999, 'ucrl2': 57743.30000000008}
# 2021-02-19 15:00:51.968600, Episode 3970, cumulative total regret: {'ucrl2_mc': 21641.399999999987, 'ucrl2': 57779.90000000009}
# 2021-02-19 15:01:38.337625, Episode 3980, cumulative total regret: {'ucrl2_mc': 21658.09999999998, 'ucrl2': 57809.60000000008}
# 2021-02-19 15:02:23.361819, Episode 3990, cumulative total regret: {'ucrl2_mc': 21711.899999999983, 'ucrl2': 57855.20000000008}
# 2021-02-19 15:03:08.750466, Episode 4000, cumulative total regret: {'ucrl2_mc': 21737.399999999987, 'ucrl2': 57902.00000000007}
# 2021-02-19 15:03:51.994283, Episode 4010, cumulative total regret: {'ucrl2_mc': 21778.999999999985, 'ucrl2': 57899.60000000007}
# 2021-02-19 15:04:35.369173, Episode 4020, cumulative total regret: {'ucrl2_mc': 21784.29999999999, 'ucrl2': 57913.80000000007}
# 2021-02-19 15:05:17.892746, Episode 4030, cumulative total regret: {'ucrl2_mc': 21784.299999999992, 'ucrl2': 57933.50000000007}
# 2021-02-19 15:06:00.658544, Episode 4040, cumulative total regret: {'ucrl2_mc': 21830.799999999992, 'ucrl2': 57951.20000000007}
# 2021-02-19 15:06:44.138452, Episode 4050, cumulative total regret: {'ucrl2_mc': 21885.39999999999, 'ucrl2': 58004.20000000007}
# 2021-02-19 15:07:26.995674, Episode 4060, cumulative total regret: {'ucrl2_mc': 21887.499999999985, 'ucrl2': 58000.10000000008}
# 2021-02-19 15:08:09.208840, Episode 4070, cumulative total regret: {'ucrl2_mc': 21892.299999999977, 'ucrl2': 58001.70000000008}
# 2021-02-19 15:08:51.818143, Episode 4080, cumulative total regret: {'ucrl2_mc': 21922.399999999976, 'ucrl2': 58055.20000000008}
# 2021-02-19 15:09:34.355484, Episode 4090, cumulative total regret: {'ucrl2_mc': 21963.499999999978, 'ucrl2': 58083.400000000074}
# 2021-02-19 15:10:17.238722, Episode 4100, cumulative total regret: {'ucrl2_mc': 21966.599999999977, 'ucrl2': 58103.500000000065}
# 2021-02-19 15:10:59.910895, Episode 4110, cumulative total regret: {'ucrl2_mc': 21997.999999999978, 'ucrl2': 58119.400000000074}
# 2021-02-19 15:11:41.565931, Episode 4120, cumulative total regret: {'ucrl2_mc': 22017.799999999974, 'ucrl2': 58140.30000000006}
# 2021-02-19 15:12:25.216988, Episode 4130, cumulative total regret: {'ucrl2_mc': 22042.39999999998, 'ucrl2': 58155.30000000006}
# 2021-02-19 15:13:07.913014, Episode 4140, cumulative total regret: {'ucrl2_mc': 22044.39999999998, 'ucrl2': 58174.500000000065}
# 2021-02-19 15:13:49.201817, Episode 4150, cumulative total regret: {'ucrl2_mc': 22045.899999999983, 'ucrl2': 58217.600000000064}
# 2021-02-19 15:14:30.739461, Episode 4160, cumulative total regret: {'ucrl2_mc': 22021.99999999998, 'ucrl2': 58232.600000000064}
# 2021-02-19 15:15:12.825081, Episode 4170, cumulative total regret: {'ucrl2_mc': 22047.59999999998, 'ucrl2': 58244.40000000007}
# 2021-02-19 15:15:55.330636, Episode 4180, cumulative total regret: {'ucrl2_mc': 22054.599999999984, 'ucrl2': 58278.600000000064}
# 2021-02-19 15:16:37.698145, Episode 4190, cumulative total regret: {'ucrl2_mc': 22053.199999999983, 'ucrl2': 58319.60000000008}
# 2021-02-19 15:17:19.969036, Episode 4200, cumulative total regret: {'ucrl2_mc': 22111.199999999986, 'ucrl2': 58378.30000000008}
# 2021-02-19 15:18:01.943326, Episode 4210, cumulative total regret: {'ucrl2_mc': 22132.099999999984, 'ucrl2': 58405.50000000007}
# 2021-02-19 15:18:43.401081, Episode 4220, cumulative total regret: {'ucrl2_mc': 22179.799999999985, 'ucrl2': 58448.20000000007}
# 2021-02-19 15:19:25.343352, Episode 4230, cumulative total regret: {'ucrl2_mc': 22217.699999999986, 'ucrl2': 58464.80000000007}
# 2021-02-19 15:20:08.164140, Episode 4240, cumulative total regret: {'ucrl2_mc': 22250.999999999985, 'ucrl2': 58493.80000000007}
# 2021-02-19 15:20:49.399094, Episode 4250, cumulative total regret: {'ucrl2_mc': 22259.699999999986, 'ucrl2': 58522.100000000064}
# 2021-02-19 15:21:31.231729, Episode 4260, cumulative total regret: {'ucrl2_mc': 22258.899999999983, 'ucrl2': 58575.70000000007}
# 2021-02-19 15:22:12.427254, Episode 4270, cumulative total regret: {'ucrl2_mc': 22288.199999999983, 'ucrl2': 58597.600000000064}
# 2021-02-19 15:22:54.647993, Episode 4280, cumulative total regret: {'ucrl2_mc': 22307.299999999985, 'ucrl2': 58627.500000000065}
# 2021-02-19 15:23:36.442027, Episode 4290, cumulative total regret: {'ucrl2_mc': 22318.699999999986, 'ucrl2': 58636.60000000006}
# 2021-02-19 15:24:18.805397, Episode 4300, cumulative total regret: {'ucrl2_mc': 22335.199999999986, 'ucrl2': 58664.40000000007}
# 2021-02-19 15:25:00.893108, Episode 4310, cumulative total regret: {'ucrl2_mc': 22359.499999999985, 'ucrl2': 58681.30000000006}
# 2021-02-19 15:25:42.259728, Episode 4320, cumulative total regret: {'ucrl2_mc': 22399.899999999983, 'ucrl2': 58715.60000000007}
# 2021-02-19 15:26:24.308821, Episode 4330, cumulative total regret: {'ucrl2_mc': 22403.99999999998, 'ucrl2': 58704.00000000007}
# 2021-02-19 15:27:06.408212, Episode 4340, cumulative total regret: {'ucrl2_mc': 22443.799999999977, 'ucrl2': 58749.20000000007}
# 2021-02-19 15:27:48.035675, Episode 4350, cumulative total regret: {'ucrl2_mc': 22439.89999999998, 'ucrl2': 58753.60000000008}
# 2021-02-19 15:28:30.195592, Episode 4360, cumulative total regret: {'ucrl2_mc': 22443.999999999978, 'ucrl2': 58761.50000000009}
# 2021-02-19 15:29:12.338701, Episode 4370, cumulative total regret: {'ucrl2_mc': 22452.899999999976, 'ucrl2': 58787.30000000009}
# 2021-02-19 15:29:53.751541, Episode 4380, cumulative total regret: {'ucrl2_mc': 22484.499999999978, 'ucrl2': 58789.90000000008}
# 2021-02-19 15:30:35.634364, Episode 4390, cumulative total regret: {'ucrl2_mc': 22498.99999999999, 'ucrl2': 58820.00000000008}
# 2021-02-19 15:31:17.693852, Episode 4400, cumulative total regret: {'ucrl2_mc': 22497.799999999992, 'ucrl2': 58812.100000000086}
# 2021-02-19 15:32:00.024572, Episode 4410, cumulative total regret: {'ucrl2_mc': 22528.39999999999, 'ucrl2': 58836.50000000008}
# 2021-02-19 15:32:42.566669, Episode 4420, cumulative total regret: {'ucrl2_mc': 22591.89999999999, 'ucrl2': 58879.70000000008}
# 2021-02-19 15:33:24.760548, Episode 4430, cumulative total regret: {'ucrl2_mc': 22605.499999999996, 'ucrl2': 58881.90000000007}
# 2021-02-19 15:34:05.422770, Episode 4440, cumulative total regret: {'ucrl2_mc': 22663.09999999999, 'ucrl2': 58945.30000000007}
# 2021-02-19 15:34:47.445686, Episode 4450, cumulative total regret: {'ucrl2_mc': 22678.49999999999, 'ucrl2': 58972.40000000008}
# 2021-02-19 15:35:29.530115, Episode 4460, cumulative total regret: {'ucrl2_mc': 22695.899999999987, 'ucrl2': 58991.70000000008}
# 2021-02-19 15:36:11.287333, Episode 4470, cumulative total regret: {'ucrl2_mc': 22713.19999999999, 'ucrl2': 58987.90000000007}
# 2021-02-19 15:36:52.672692, Episode 4480, cumulative total regret: {'ucrl2_mc': 22737.09999999999, 'ucrl2': 58958.70000000007}
# 2021-02-19 15:37:34.837781, Episode 4490, cumulative total regret: {'ucrl2_mc': 22755.899999999987, 'ucrl2': 58951.400000000074}
# 2021-02-19 15:38:14.635992, Episode 4500, cumulative total regret: {'ucrl2_mc': 22813.099999999988, 'ucrl2': 58992.000000000065}
# 2021-02-19 15:38:52.422819, Episode 4510, cumulative total regret: {'ucrl2_mc': 22846.999999999993, 'ucrl2': 59032.20000000006}
# 2021-02-19 15:39:29.600269, Episode 4520, cumulative total regret: {'ucrl2_mc': 22797.999999999993, 'ucrl2': 59050.90000000006}
# 2021-02-19 15:40:08.080883, Episode 4530, cumulative total regret: {'ucrl2_mc': 22830.599999999995, 'ucrl2': 59043.80000000006}
# 2021-02-19 15:40:46.664635, Episode 4540, cumulative total regret: {'ucrl2_mc': 22884.099999999995, 'ucrl2': 59070.400000000074}
# 2021-02-19 15:41:23.896024, Episode 4550, cumulative total regret: {'ucrl2_mc': 22921.899999999994, 'ucrl2': 59117.800000000076}
# 2021-02-19 15:42:01.232960, Episode 4560, cumulative total regret: {'ucrl2_mc': 22953.099999999995, 'ucrl2': 59111.60000000007}
# 2021-02-19 15:42:38.466042, Episode 4570, cumulative total regret: {'ucrl2_mc': 22977.799999999985, 'ucrl2': 59144.80000000007}
# 2021-02-19 15:43:15.925851, Episode 4580, cumulative total regret: {'ucrl2_mc': 22988.09999999998, 'ucrl2': 59151.40000000007}
# 2021-02-19 15:43:52.608079, Episode 4590, cumulative total regret: {'ucrl2_mc': 22971.899999999976, 'ucrl2': 59157.80000000006}
# 2021-02-19 15:44:30.157568, Episode 4600, cumulative total regret: {'ucrl2_mc': 22952.699999999975, 'ucrl2': 59157.100000000064}
# 2021-02-19 15:45:07.513003, Episode 4610, cumulative total regret: {'ucrl2_mc': 22964.199999999975, 'ucrl2': 59185.000000000065}
# 2021-02-19 15:45:43.331742, Episode 4620, cumulative total regret: {'ucrl2_mc': 22991.799999999977, 'ucrl2': 59231.40000000006}
# 2021-02-19 15:46:20.281647, Episode 4630, cumulative total regret: {'ucrl2_mc': 23055.69999999998, 'ucrl2': 59241.90000000006}
# 2021-02-19 15:46:56.630657, Episode 4640, cumulative total regret: {'ucrl2_mc': 23082.199999999975, 'ucrl2': 59238.700000000055}
# 2021-02-19 15:47:34.150446, Episode 4650, cumulative total regret: {'ucrl2_mc': 23094.199999999975, 'ucrl2': 59253.20000000006}
# 2021-02-19 15:48:10.060448, Episode 4660, cumulative total regret: {'ucrl2_mc': 23157.799999999974, 'ucrl2': 59264.100000000064}
# 2021-02-19 15:48:46.740233, Episode 4670, cumulative total regret: {'ucrl2_mc': 23173.89999999997, 'ucrl2': 59278.10000000006}
# 2021-02-19 15:49:24.265543, Episode 4680, cumulative total regret: {'ucrl2_mc': 23196.499999999967, 'ucrl2': 59313.50000000005}
# 2021-02-19 15:50:01.196712, Episode 4690, cumulative total regret: {'ucrl2_mc': 23219.59999999997, 'ucrl2': 59332.800000000054}
# 2021-02-19 15:50:38.686486, Episode 4700, cumulative total regret: {'ucrl2_mc': 23236.09999999997, 'ucrl2': 59359.40000000005}
# 2021-02-19 15:51:16.400112, Episode 4710, cumulative total regret: {'ucrl2_mc': 23244.099999999966, 'ucrl2': 59363.30000000004}
# 2021-02-19 15:51:52.948788, Episode 4720, cumulative total regret: {'ucrl2_mc': 23282.399999999965, 'ucrl2': 59393.90000000004}
# 2021-02-19 15:52:29.755156, Episode 4730, cumulative total regret: {'ucrl2_mc': 23319.599999999966, 'ucrl2': 59431.000000000044}
# 2021-02-19 15:53:06.419685, Episode 4740, cumulative total regret: {'ucrl2_mc': 23330.999999999967, 'ucrl2': 59452.00000000004}
# 2021-02-19 15:53:43.197980, Episode 4750, cumulative total regret: {'ucrl2_mc': 23327.799999999963, 'ucrl2': 59463.700000000026}
# 2021-02-19 15:54:19.025710, Episode 4760, cumulative total regret: {'ucrl2_mc': 23381.299999999963, 'ucrl2': 59481.10000000003}
# 2021-02-19 15:54:56.360431, Episode 4770, cumulative total regret: {'ucrl2_mc': 23393.699999999964, 'ucrl2': 59481.20000000003}
# 2021-02-19 15:55:33.690961, Episode 4780, cumulative total regret: {'ucrl2_mc': 23431.99999999996, 'ucrl2': 59487.00000000003}
# 2021-02-19 15:56:11.135703, Episode 4790, cumulative total regret: {'ucrl2_mc': 23439.099999999955, 'ucrl2': 59538.30000000003}
# 2021-02-19 15:56:47.845319, Episode 4800, cumulative total regret: {'ucrl2_mc': 23454.899999999958, 'ucrl2': 59574.80000000004}
# 2021-02-19 15:57:24.427223, Episode 4810, cumulative total regret: {'ucrl2_mc': 23468.399999999954, 'ucrl2': 59612.10000000004}
# 2021-02-19 15:58:02.073376, Episode 4820, cumulative total regret: {'ucrl2_mc': 23475.499999999953, 'ucrl2': 59614.20000000004}
# 2021-02-19 15:58:38.556403, Episode 4830, cumulative total regret: {'ucrl2_mc': 23477.09999999996, 'ucrl2': 59627.20000000005}
# 2021-02-19 15:59:15.248637, Episode 4840, cumulative total regret: {'ucrl2_mc': 23489.99999999996, 'ucrl2': 59649.500000000044}
# 2021-02-19 15:59:52.465967, Episode 4850, cumulative total regret: {'ucrl2_mc': 23520.499999999964, 'ucrl2': 59646.400000000045}
# 2021-02-19 16:00:28.300194, Episode 4860, cumulative total regret: {'ucrl2_mc': 23551.499999999964, 'ucrl2': 59707.900000000045}
# 2021-02-19 16:01:05.431637, Episode 4870, cumulative total regret: {'ucrl2_mc': 23607.59999999996, 'ucrl2': 59728.40000000005}
# 2021-02-19 16:01:42.081788, Episode 4880, cumulative total regret: {'ucrl2_mc': 23620.499999999956, 'ucrl2': 59773.40000000005}
# 2021-02-19 16:02:19.428148, Episode 4890, cumulative total regret: {'ucrl2_mc': 23618.899999999954, 'ucrl2': 59779.60000000006}
# 2021-02-19 16:02:56.742812, Episode 4900, cumulative total regret: {'ucrl2_mc': 23668.19999999995, 'ucrl2': 59815.300000000054}
# 2021-02-19 16:03:34.137848, Episode 4910, cumulative total regret: {'ucrl2_mc': 23661.29999999995, 'ucrl2': 59822.40000000005}
# 2021-02-19 16:04:10.835159, Episode 4920, cumulative total regret: {'ucrl2_mc': 23670.199999999946, 'ucrl2': 59847.60000000005}
# 2021-02-19 16:04:48.546629, Episode 4930, cumulative total regret: {'ucrl2_mc': 23687.599999999948, 'ucrl2': 59880.20000000004}
# 2021-02-19 16:05:25.451355, Episode 4940, cumulative total regret: {'ucrl2_mc': 23750.099999999944, 'ucrl2': 59919.30000000004}
# 2021-02-19 16:06:01.746806, Episode 4950, cumulative total regret: {'ucrl2_mc': 23776.89999999994, 'ucrl2': 59934.20000000003}
# 2021-02-19 16:06:37.823557, Episode 4960, cumulative total regret: {'ucrl2_mc': 23781.999999999938, 'ucrl2': 59949.300000000025}
# 2021-02-19 16:07:15.993388, Episode 4970, cumulative total regret: {'ucrl2_mc': 23814.19999999994, 'ucrl2': 59975.80000000002}
# 2021-02-19 16:07:52.985112, Episode 4980, cumulative total regret: {'ucrl2_mc': 23825.699999999946, 'ucrl2': 59981.4}
# 2021-02-19 16:08:29.955769, Episode 4990, cumulative total regret: {'ucrl2_mc': 23852.699999999946, 'ucrl2': 60007.600000000006}

# %%
''' plot the regret results for multiple teams (Figure 5) '''

# you can run the above cell or load the saved regret results 

# for figure 4(b) load file `total_regret_0`, for figure 4(a) load file `total_regret_01`
with open('outputs/agents/multiple_teams/total_regret_1', 'rb') as file:
    regrets = pickle.load(file)

width = 1.3
height = 1

latexify(fig_height=height, fig_width=width, font_size=7, legend_size=5)
line_width = 0.8
line_style='solid'

plt.figure(1)
fig, ax = plt.subplots()
ax = format_axes(ax)
ax.ticklabel_format(style='sci', scilimits=(3, 3), axis='y')
ax.ticklabel_format(style='sci', scilimits=(3, 3), axis='x')
ax.set_ylabel(r'Regret, $R(T)$')
ax.set_xlabel(r'Episode, $k$')

ax.plot(np.cumsum(regrets['ucrl2_mc']),color=COLORS[0], label=r'UCRL2-MC', linestyle=line_style,
        linewidth=line_width)
ax.plot(np.cumsum(regrets['ucrl2']), color=COLORS[1], label=r'UCRL2', linestyle=line_style,
        linewidth=line_width)

ax.legend(frameon=False, loc=(0.0, 0.76))
plt.subplots_adjust(left=0.23, bottom=0.28, right=0.98, top=0.87, wspace=0, hspace=0)
# plt.show()
fig.savefig('outputs/multiple_teams_s1.pdf')
plt.close()
